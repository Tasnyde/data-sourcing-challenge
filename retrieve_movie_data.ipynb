# %% [markdown]
# ### Import Required Libraries and Set Up Environment Variables

# %%
# Import libraries and Set up environment
# Dependencies
import requests
import time
from dotenv import load_dotenv
import os
import pandas as pd
import json

# %%
# Set environment variables from the .env in the local environment
load_dotenv()

nyt_api_key = os.getenv("NYT_API_KEY")
tmdb_api_key = os.getenv("TMDB_API_KEY")

# %% [markdown]
# ### Access the New York Times API

# %%
# Access the API key environment variable
# Set the base URL

url = "https://api.nytimes.com/svc/search/v2/articlesearch.json?"

# Filter for movie reviews with "love" in the headline
# section_name should be "Movies"
# type_of_material should be "Review"
filter_query = 'section_name:"Movies" AND type_of_material:"Review" AND headline:"love"'

# Use a sort filter, sort by newest
sort = "newest"

# Select the following fields to return:
# headline, web_url, snippet, source, keywords, pub_date, byline, word_count
field_list = "headline,web_url,snippet,source,keywords,pub_date,byline,word_count"

# Search for reviews published between a begin and end date
begin_date = "20130101"
end_date = "20230531"

# Build URL
query_url = (
    f"{url}api-key={nyt_api_key}&begin_date={begin_date}&end_date={end_date}"
    + f'&fq={filter_query}&sort={sort}&fl={field_list}'
)
print(query_url)
# Out:
# https://api.nytimes.com/svc/search/v2/articlesearch.json?api-key=sqVG6wgAGcAXT54v97qbnqBrN3jjd6SC&begin_date=20130101&end_date=20230531&fq=section_name:"Movies" AND type_of_material:"Review" AND headline:"love"&sort=newest&fl=headline,web_url,snippet,source,keywords,pub_date,byline,word_count

# %%
# Create an empty list to store the reviews
reviews_list = []

# loop through pages 0-19
for page in range(0,20):
    
    # create query with a page number
    # API results show 10 articles at a time
    page_query_url = f"{query_url}&page={page}" 

    # Make a "GET" request and retrieve the JSON
    response = requests.get(page_query_url).json()
    
    # add a twelve second interval between queries to avoid hitting the API too quickly
    time.sleep(12)

    # Try and save the reviews to the reviews_list
    try:
        reviews = response
        for review in reviews["response"]["docs"]:
            reviews_list.append(review)
        print(f"Checked page {page}") 

        # loop through the reviews["response"]["docs"] and append each review to the list

        
        # Print the page that was just retrieved
    except:     
        print(f"Page {page} not retrieved")
        break
        # Print the page number that had no results then break from the loop
    print(f"Total reviews retrieved: {len(reviews_list)}")
# Out:
# Checked page 0
# Total reviews retrieved: 10
# Checked page 1
# Total reviews retrieved: 20
# Checked page 2
# Total reviews retrieved: 30
# Checked page 3
# Total reviews retrieved: 40
# Checked page 4
# Total reviews retrieved: 50
# Checked page 5
# Total reviews retrieved: 60
# Checked page 6
# Total reviews retrieved: 70
# Checked page 7
# Total reviews retrieved: 80
# Checked page 8
# Total reviews retrieved: 90
# Checked page 9
# Total reviews retrieved: 100
# Checked page 10
# Total reviews retrieved: 110
# Checked page 11
# Total reviews retrieved: 120
# Checked page 12
# Total reviews retrieved: 130
# Checked page 13
# Total reviews retrieved: 140
# Checked page 14
# Total reviews retrieved: 150
# Checked page 15
# Total reviews retrieved: 160
# Checked page 16
# Total reviews retrieved: 170
# Checked page 17
# Total reviews retrieved: 180
# Checked page 18
# Total reviews retrieved: 190
# Checked page 19
# Total reviews retrieved: 200

# %%
# Preview the first 5 results in JSON format
num_reviews_to_preview = min(5, len(reviews_list))
for review in reviews_list[:num_reviews_to_preview]:
    print(json.dumps(review, indent=4))
# Use json.dumps with argument indent=4 to format data

print(json.dumps(reviews_list, indent=4))
# Out:
# {
#     "web_url": "https://www.nytimes.com/2023/05/25/movies/the-attachment-diaries-review.html",
#     "snippet": "A gynecologist and her patient form a horrifyingly twisted connection in this batty, bloody Argentine melodrama.",
#     "source": "The New York Times",
#     "headline": {
#         "main": "\u2018The Attachment Diaries\u2019 Review: Love, Sick",
#         "kicker": null,
#         "content_kicker": null,
#         "print_headline": "The Attachment Diaries",
#         "name": null,
#         "seo": null,
#         "sub": null
#     },
#     "keywords": [
#         {
#             "name": "subject",
#             "value": "Movies",
#             "rank": 1,
#             "major": "N"
#         },
#         {
#             "name": "creative_works",
#             "value": "The Attachment Diaries (Movie)",
#             "rank": 2,
#             "major": "N"
#         },
#         {
#             "name": "persons",
#             "value": "Diment, Valentin Javier",
#             "rank": 3,
#             "major": "N"
#         }
#     ],
#     "pub_date": "2023-05-25T11:00:03+0000",
#     "byline": {
#         "original": "By Jeannette Catsoulis",
#         "person": [
#             {
#                 "firstname": "Jeannette",
#                 "middlename": null,
#                 "lastname": "Catsoulis",
#                 "qualifier": null,
#                 "title": null,
#                 "role": "reported",
#                 "organization": "",
#                 "rank": 1
#             }
#         ],
#         "organization": null
#     },
#     "word_count": 295
# }
# {
#     "web_url": "https://www.nytimes.com/2023/05/04/movies/whats-love-got-to-do-with-it-review.html",
#     "snippet": "Two childhood friends navigate cultural differences in this pleasantly uncontentious romantic comedy.",
#     "source": "The New York Times",
#     "headline": {
#         "main": "Review: \u2018What\u2019s Love Got to Do With It?\u2019 Probably a Lot",
#         "kicker": null,
#         "content_kicker": null,
#         "print_headline": "What\u2019s Love Got to Do With It?",
#         "name": null,
#         "seo": null,
#         "sub": null
#     },
#     "keywords": [
#         {
#             "name": "subject",
#             "value": "Movies",
#             "rank": 1,
#             "major": "N"
#         },
#         {
#             "name": "persons",
#             "value": "Kapur, Shekhar",
#             "rank": 2,
#             "major": "N"
#         },
#         {
#             "name": "persons",
#             "value": "James, Lily",
#             "rank": 3,
#             "major": "N"
#         },
#         {
#             "name": "persons",
#             "value": "Azmi, Shabana",
#             "rank": 4,
#             "major": "N"
#         },
#         {
#             "name": "persons",
#             "value": "Thompson, Emma",
#             "rank": 5,
#             "major": "N"
#         }
#     ],
#     "pub_date": "2023-05-04T17:16:45+0000",
#     "byline": {
#         "original": "By Jeannette Catsoulis",
#         "person": [
#             {
#                 "firstname": "Jeannette",
#                 "middlename": null,
#                 "lastname": "Catsoulis",
#                 "qualifier": null,
#                 "title": null,
#                 "role": "reported",
#                 "organization": "",
#                 "rank": 1
#             }
#         ],
#         "organization": null
#     },
#     "word_count": 287
# }
# {
#     "web_url": "https://www.nytimes.com/2023/05/04/movies/you-can-live-forever-review.html",
#     "snippet": "Religion comes between two girls falling in love in the 1990s in this sweet coming-of-age film bathed in grunge hues.",
#     "source": "The New York Times",
#     "headline": {
#         "main": "\u2018You Can Live Forever\u2019 Review: Do You Love Me Now?",
#         "kicker": null,
#         "content_kicker": null,
#         "print_headline": "You Can Live Forever",
#         "name": null,
#         "seo": null,
#         "sub": null
#     },
#     "keywords": [
#         {
#             "name": "subject",
#             "value": "Movies",
#             "rank": 1,
#             "major": "N"
#         },
#         {
#             "name": "creative_works",
#             "value": "You Can Live Forever (Movie)",
#             "rank": 2,
#             "major": "N"
#         },
#         {
#             "name": "persons",
#             "value": "Slutsky, Mark",
#             "rank": 3,
#             "major": "N"
#         },
#         {
#             "name": "persons",
#             "value": "Watts, Sarah (Film Director)",
#             "rank": 4,
#             "major": "N"
#         },
#         {
#             "name": "persons",
#             "value": "O'Driscoll, Anwen",
#             "rank": 5,
#             "major": "N"
#         },
#         {
#             "name": "persons",
#             "value": "Laporte, June (Actor)",
#             "rank": 6,
#             "major": "N"
#         }
#     ],
#     "pub_date": "2023-05-04T11:00:08+0000",
#     "byline": {
#         "original": "By Elisabeth Vincentelli",
#         "person": [
#             {
#                 "firstname": "Elisabeth",
#                 "middlename": null,
#                 "lastname": "Vincentelli",
#                 "qualifier": null,
#                 "title": null,
#                 "role": "reported",
#                 "organization": "",
#                 "rank": 1
#             }
#         ],
#         "organization": null
#     },
#     "word_count": 294
# }
# {
#     "web_url": "https://www.nytimes.com/2023/04/21/movies/a-tourists-guide-to-love-review.html",
#     "snippet": "Rachael Leigh Cook stars in this bland rom-com as a travel executive exploring Vietnam and getting over a breakup.",
#     "source": "The New York Times",
#     "headline": {
#         "main": "\u2018A Tourist\u2019s Guide to Love\u2019 Review: A Wearyingly Familiar Trip",
#         "kicker": null,
#         "content_kicker": null,
#         "print_headline": "A Tourist\u2019s  Guide to Love",
#         "name": null,
#         "seo": null,
#         "sub": null
#     },
#     "keywords": [
#         {
#             "name": "subject",
#             "value": "Movies",
#             "rank": 1,
#             "major": "N"
#         },
#         {
#             "name": "creative_works",
#             "value": "A Tourist's Guide to Love (Movie)",
#             "rank": 2,
#             "major": "N"
#         },
#         {
#             "name": "persons",
#             "value": "Tsuchida, Steven",
#             "rank": 3,
#             "major": "N"
#         },
#         {
#             "name": "persons",
#             "value": "Cook, Rachael Leigh",
#             "rank": 4,
#             "major": "N"
#         }
#     ],
#     "pub_date": "2023-04-21T07:03:25+0000",
#     "byline": {
#         "original": "By Elisabeth Vincentelli",
#         "person": [
#             {
#                 "firstname": "Elisabeth",
#                 "middlename": null,
#                 "lastname": "Vincentelli",
#                 "qualifier": null,
#                 "title": null,
#                 "role": "reported",
#                 "organization": "",
#                 "rank": 1
#             }
#         ],
#         "organization": null
#     },
#     "word_count": 276
# }
# {
#     "web_url": "https://www.nytimes.com/2023/04/20/movies/other-peoples-children-review.html",
#     "snippet": "A radiant Virginie Efira stars as a Parisian teacher who blissfully falls for a man and his 4-year-old daughter, complicating everyone\u2019s lives.",
#     "source": "The New York Times",
#     "headline": {
#         "main": "\u2018Other People\u2019s Children\u2019 Review: True Romance",
#         "kicker": "Critic\u2019s pick",
#         "content_kicker": null,
#         "print_headline": "Intoxicating Love With a Sobering Turn",
#         "name": null,
#         "seo": null,
#         "sub": null
#     },
#     "keywords": [
#         {
#             "name": "subject",
#             "value": "Movies",
#             "rank": 1,
#             "major": "N"
#         },
#         {
#             "name": "persons",
#             "value": "Zlotowski, Rebecca",
#             "rank": 2,
#             "major": "N"
#         },
#         {
#             "name": "creative_works",
#             "value": "Other People's Children (Movie)",
#             "rank": 3,
#             "major": "N"
#         }
#     ],
#     "pub_date": "2023-04-20T15:35:13+0000",
#     "byline": {
#         "original": "By Manohla Dargis",
#         "person": [
#             {
#                 "firstname": "Manohla",
#                 "middlename": null,
#                 "lastname": "Dargis",
#                 "qualifier": null,
#                 "title": null,
#                 "role": "reported",
#                 "organization": "",
#                 "rank": 1
#             }
#         ],
#         "organization": null
#     },
#     "word_count": 801
# }
# [
#     {
#         "web_url": "https://www.nytimes.com/2023/05/25/movies/the-attachment-diaries-review.html",
#         "snippet": "A gynecologist and her patient form a horrifyingly twisted connection in this batty, bloody Argentine melodrama.",
#         "source": "The New York Times",
#         "headline": {
#             "main": "\u2018The Attachment Diaries\u2019 Review: Love, Sick",
#             "kicker": null,
#             "content_kicker": null,
#             "print_headline": "The Attachment Diaries",
#             "name": null,
#             "seo": null,
#             "sub": null
#         },
#         "keywords": [
#             {
#                 "name": "subject",
#                 "value": "Movies",
#                 "rank": 1,
#                 "major": "N"
#             },
#             {
#                 "name": "creative_works",
#                 "value": "The Attachment Diaries (Movie)",
#                 "rank": 2,
#                 "major": "N"
#             },
#             {
#                 "name": "persons",
#                 "value": "Diment, Valentin Javier",
#                 "rank": 3,
#                 "major": "N"
#             }
#         ],
#         "pub_date": "2023-05-25T11:00:03+0000",
#         "byline": {
#             "original": "By Jeannette Catsoulis",
#             "person": [
#                 {
#                     "firstname": "Jeannette",
#                     "middlename": null,
#                     "lastname": "Catsoulis",
#                     "qualifier": null,
#                     "title": null,
#                     "role": "reported",
#                     "organization": "",
#                     "rank": 1
#                 }
#             ],
#             "organization": null
#         },
#         "word_count": 295
#     },
#     {
#         "web_url": "https://www.nytimes.com/2023/05/04/movies/whats-love-got-to-do-with-it-review.html",
#         "snippet": "Two childhood friends navigate cultural differences in this pleasantly uncontentious romantic comedy.",
#         "source": "The New York Times",
#         "headline": {
#             "main": "Review: \u2018What\u2019s Love Got to Do With It?\u2019 Probably a Lot",
#             "kicker": null,
#             "content_kicker": null,
#             "print_headline": "What\u2019s Love Got to Do With It?",
#             "name": null,
#             "seo": null,
#             "sub": null
#         },
#         "keywords": [
#             {
#                 "name": "subject",
#                 "value": "Movies",
#                 "rank": 1,
#                 "major": "N"
#             },
#             {
#                 "name": "persons",
#                 "value": "Kapur, Shekhar",
#                 "rank": 2,
#                 "major": "N"
#             },
#             {
#                 "name": "persons",
#                 "value": "James, Lily",
#                 "rank": 3,
#                 "major": "N"
#             },
#             {
#                 "name": "persons",
#                 "value": "Azmi, Shabana",
#                 "rank": 4,
#                 "major": "N"
#             },
#             {
#                 "name": "persons",
#                 "value": "Thompson, Emma",
#                 "rank": 5,
#                 "major": "N"
#             }
#         ],
#         "pub_date": "2023-05-04T17:16:45+0000",
#         "byline": {
#             "original": "By Jeannette Catsoulis",
#             "person": [
#                 {
#                     "firstname": "Jeannette",
#                     "middlename": null,
#                     "lastname": "Catsoulis",
#                     "qualifier": null,
#                     "title": null,
#                     "role": "reported",
#                     "organization": "",
#                     "rank": 1
#                 }
#             ],
#             "organization": null
#         },
#         "word_count": 287
#     },
#     {
#         "web_url": "https://www.nytimes.com/2023/05/04/movies/you-can-live-forever-review.html",
#         "snippet": "Religion comes between two girls falling in love in the 1990s in this sweet coming-of-age film bathed in grunge hues.",
#         "source": "The New York Times",
#         "headline": {
#             "main": "\u2018You Can Live Forever\u2019 Review: Do You Love Me Now?",
#             "kicker": null,
#             "content_kicker": null,
#             "print_headline": "You Can Live Forever",
#             "name": null,
#             "seo": null,
#             "sub": null
#         },
#         "keywords": [
#             {
#                 "name": "subject",
#                 "value": "Movies",
#                 "rank": 1,
#                 "major": "N"
#             },
#             {
#                 "name": "creative_works",
#                 "value": "You Can Live Forever (Movie)",
#                 "rank": 2,
#                 "major": "N"
#             },
#             {
#                 "name": "persons",
#                 "value": "Slutsky, Mark",
#                 "rank": 3,
#                 "major": "N"
#             },
#             {
#                 "name": "persons",
#                 "value": "Watts, Sarah (Film Director)",
#                 "rank": 4,
#                 "major": "N"
#             },
#             {
#                 "name": "persons",
#                 "value": "O'Driscoll, Anwen",
#                 "rank": 5,
#                 "major": "N"
#             },
#             {
#                 "name": "persons",
#                 "value": "Laporte, June (Actor)",
#                 "rank": 6,
#                 "major": "N"
#             }
#         ],
#         "pub_date": "2023-05-04T11:00:08+0000",
#         "byline": {
#             "original": "By Elisabeth Vincentelli",
#             "person": [
#                 {
#                     "firstname": "Elisabeth",
#                     "middlename": null,
#                     "lastname": "Vincentelli",
#                     "qualifier": null,
#                     "title": null,
#                     "role": "reported",
#                     "organization": "",
#                     "rank": 1
#                 }
#             ],
#             "organization": null
#         },
#         "word_count": 294
#     },
#     {
#         "web_url": "https://www.nytimes.com/2023/04/21/movies/a-tourists-guide-to-love-review.html",
#         "snippet": "Rachael Leigh Cook stars in this bland rom-com as a travel executive exploring Vietnam and getting over a breakup.",
#         "source": "The New York Times",
#         "headline": {
#             "main": "\u2018A Tourist\u2019s Guide to Love\u2019 Review: A Wearyingly Familiar Trip",
#             "kicker": null,
#             "content_kicker": null,
#             "print_headline": "A Tourist\u2019s  Guide to Love",
#             "name": null,
#             "seo": null,
#             "sub": null
#         },
#         "keywords": [
#             {
#                 "name": "subject",
#                 "value": "Movies",
#                 "rank": 1,
#                 "major": "N"
#             },
#             {
#                 "name": "creative_works",
#                 "value": "A Tourist's Guide to Love (Movie)",
#                 "rank": 2,
#                 "major": "N"
#             },
#             {
#                 "name": "persons",
#                 "value": "Tsuchida, Steven",
#                 "rank": 3,
#                 "major": "N"
#             },
#             {
#                 "name": "persons",
#                 "value": "Cook, Rachael Leigh",
#                 "rank": 4,
#                 "major": "N"
#             }
#         ],
#         "pub_date": "2023-04-21T07:03:25+0000",
#         "byline": {
#             "original": "By Elisabeth Vincentelli",
#             "person": [
#                 {
#                     "firstname": "Elisabeth",
#                     "middlename": null,
#                     "lastname": "Vincentelli",
#                     "qualifier": null,
#                     "title": null,
#                     "role": "reported",
#                     "organization": "",
#                     "rank": 1
#                 }
#             ],
#             "organization": null
#         },
#         "word_count": 276
#     },
#     {
#         "web_url": "https://www.nytimes.com/2023/04/20/movies/other-peoples-children-review.html",
#         "snippet": "A radiant Virginie Efira stars as a Parisian teacher who blissfully falls for a man and his 4-year-old daughter, complicating everyone\u2019s lives.",
#         "source": "The New York Times",
#         "headline": {
#             "main": "\u2018Other People\u2019s Children\u2019 Review: True Romance",
#             "kicker": "Critic\u2019s pick",
#             "content_kicker": null,
#             "print_headline": "Intoxicating Love With a Sobering Turn",
#             "name": null,
#             "seo": null,
#             "sub": null
#         },
#         "keywords": [
#             {
#                 "name": "subject",
#                 "value": "Movies",
#                 "rank": 1,
#                 "major": "N"
#             },
#             {
#                 "name": "persons",
#                 "value": "Zlotowski, Rebecca",
#                 "rank": 2,
#                 "major": "N"
#             },
#             {
#                 "name": "creative_works",
#                 "value": "Other People's Children (Movie)",
#                 "rank": 3,
#                 "major": "N"
#             }
#         ],
#         "pub_date": "2023-04-20T15:35:13+0000",
#         "byline": {
#             "original": "By Manohla Dargis",
#             "person": [
#                 {
#                     "firstname": "Manohla",
#                     "middlename": null,
#                     "lastname": "Dargis",
#                     "qualifier": null,
#                     "title": null,
#                     "role": "reported",
#                     "organization": "",
#                     "rank": 1
#                 }
#             ],
#             "organization": null
#         },
#         "word_count": 801
#     },
#     {
#         "web_url": "https://www.nytimes.com/2023/04/13/movies/one-true-loves-movie-review.html",
#         "snippet": "A film adaptation of Taylor Jenkins Reid\u2019s novel has potential for drama, but it stumbles on stock melodrama.",
#         "source": "The New York Times",
#         "headline": {
#             "main": "\u2018One True Loves\u2019 Review: A Romance Lost at Sea",
#             "kicker": null,
#             "content_kicker": null,
#             "print_headline": "One True Loves",
#             "name": null,
#             "seo": null,
#             "sub": null
#         },
#         "keywords": [
#             {
#                 "name": "subject",
#                 "value": "Movies",
#                 "rank": 1,
#                 "major": "N"
#             },
#             {
#                 "name": "persons",
#                 "value": "Bracey, Luke (1989- )",
#                 "rank": 2,
#                 "major": "N"
#             },
#             {
#                 "name": "persons",
#                 "value": "Liu, Simu",
#                 "rank": 3,
#                 "major": "N"
#             },
#             {
#                 "name": "persons",
#                 "value": "Reid, Taylor Jenkins",
#                 "rank": 4,
#                 "major": "N"
#             },
#             {
#                 "name": "persons",
#                 "value": "Soo, Phillipa",
#                 "rank": 5,
#                 "major": "N"
#             },
#             {
#                 "name": "persons",
#                 "value": "Fickman, Andy",
#                 "rank": 6,
#                 "major": "N"
#             },
#             {
#                 "name": "creative_works",
#                 "value": "One True Loves (Movie)",
#                 "rank": 7,
#                 "major": "N"
#             }
#         ],
#         "pub_date": "2023-04-13T11:00:06+0000",
#         "byline": {
#             "original": "By Brandon Yu",
#             "person": [
#                 {
#                     "firstname": "Brandon",
#                     "middlename": null,
#                     "lastname": "Yu",
#                     "qualifier": null,
#                     "title": null,
#                     "role": "reported",
#                     "organization": "",
#                     "rank": 1
#                 }
#             ],
#             "organization": null
#         },
#         "word_count": 320
#     },
#     {
#         "web_url": "https://www.nytimes.com/2023/04/13/movies/the-lost-weekend-a-love-story-review.html",
#         "snippet": "There\u2019s not much Lennon music heard in this doc about his affair with May Pang, and given how much Pang trashes his wife, Yoko Ono, it\u2019s no surprise it was withheld.",
#         "source": "The New York Times",
#         "headline": {
#             "main": "\u2018The Lost Weekend: A Love Story\u2019 Review: When John Lennon Strayed",
#             "kicker": null,
#             "content_kicker": null,
#             "print_headline": "The Lost Weekend:  A Love Story",
#             "name": null,
#             "seo": null,
#             "sub": null
#         },
#         "keywords": [
#             {
#                 "name": "subject",
#                 "value": "Documentary Films and Programs",
#                 "rank": 1,
#                 "major": "N"
#             },
#             {
#                 "name": "creative_works",
#                 "value": "The Lost Weekend: A Love Story (Movie)",
#                 "rank": 2,
#                 "major": "N"
#             },
#             {
#                 "name": "persons",
#                 "value": "Pang, May",
#                 "rank": 3,
#                 "major": "N"
#             },
#             {
#                 "name": "persons",
#                 "value": "Lennon, John",
#                 "rank": 4,
#                 "major": "N"
#             },
#             {
#                 "name": "persons",
#                 "value": "Ono, Yoko",
#                 "rank": 5,
#                 "major": "N"
#             },
#             {
#                 "name": "persons",
#                 "value": "Brandstein, Eve",
#                 "rank": 6,
#                 "major": "N"
#             },
#             {
#                 "name": "persons",
#                 "value": "Kaufman, Richard S (Filmmaker)",
#                 "rank": 7,
#                 "major": "N"
#             },
#             {
#                 "name": "persons",
#                 "value": "Samuels, Stuart (Filmmaker)",
#                 "rank": 8,
#                 "major": "N"
#             },
#             {
#                 "name": "subject",
#                 "value": "Content Type: Personal Profile",
#                 "rank": 9,
#                 "major": "N"
#             },
#             {
#                 "name": "subject",
#                 "value": "Pop and Rock Music",
#                 "rank": 10,
#                 "major": "N"
#             }
#         ],
#         "pub_date": "2023-04-13T11:00:03+0000",
#         "byline": {
#             "original": "By Glenn Kenny",
#             "person": [
#                 {
#                     "firstname": "Glenn",
#                     "middlename": null,
#                     "lastname": "Kenny",
#                     "qualifier": null,
#                     "title": null,
#                     "role": "reported",
#                     "organization": "",
#                     "rank": 1
#                 }
#             ],
#             "organization": null
#         },
#         "word_count": 327
#     },
#     {
#         "web_url": "https://www.nytimes.com/2023/03/30/movies/a-thousand-and-one-review.html",
#         "snippet": "A mesmerizing Teyana Taylor stars in A.V. Rockwell\u2019s feature directing debut, about motherhood and survival in a fast-changing city.",
#         "source": "The New York Times",
#         "headline": {
#             "main": "\u2018A Thousand and One\u2019 Review: A New York Love Story",
#             "kicker": "Critic\u2019s Pick",
#             "content_kicker": null,
#             "print_headline": "An Unbending Will Meets a Shifting City",
#             "name": null,
#             "seo": null,
#             "sub": null
#         },
#         "keywords": [
#             {
#                 "name": "subject",
#                 "value": "Movies",
#                 "rank": 1,
#                 "major": "N"
#             },
#             {
#                 "name": "creative_works",
#                 "value": "A Thousand and One (Movie)",
#                 "rank": 2,
#                 "major": "N"
#             },
#             {
#                 "name": "persons",
#                 "value": "Rockwell, AV (Film Director)",
#                 "rank": 3,
#                 "major": "N"
#             },
#             {
#                 "name": "persons",
#                 "value": "Taylor, Teyana (1990- )",
#                 "rank": 4,
#                 "major": "N"
#             }
#         ],
#         "pub_date": "2023-03-30T18:53:42+0000",
#         "byline": {
#             "original": "By Manohla Dargis",
#             "person": [
#                 {
#                     "firstname": "Manohla",
#                     "middlename": null,
#                     "lastname": "Dargis",
#                     "qualifier": null,
#                     "title": null,
#                     "role": "reported",
#                     "organization": "",
#                     "rank": 1
#                 }
#             ],
#             "organization": null
#         },
#         "word_count": 971
#     },
#     {
#         "web_url": "https://www.nytimes.com/2023/02/09/movies/your-place-or-mine-review.html",
#         "snippet": "This humdrum Netflix romantic comedy features Reese Witherspoon and Ashton Kutcher as longtime friends with possibly hidden feelings for each other.",
#         "source": "The New York Times",
#         "headline": {
#             "main": "\u2018Your Place or Mine\u2019 Review: Try Neither",
#             "kicker": null,
#             "content_kicker": null,
#             "print_headline": "They Have a Humdrum Kind of Love",
#             "name": null,
#             "seo": null,
#             "sub": null
#         },
#         "keywords": [
#             {
#                 "name": "subject",
#                 "value": "Movies",
#                 "rank": 1,
#                 "major": "N"
#             },
#             {
#                 "name": "creative_works",
#                 "value": "Your Place or Mine (Movie)",
#                 "rank": 2,
#                 "major": "N"
#             },
#             {
#                 "name": "persons",
#                 "value": "Witherspoon, Reese",
#                 "rank": 3,
#                 "major": "N"
#             },
#             {
#                 "name": "persons",
#                 "value": "Kutcher, Ashton",
#                 "rank": 4,
#                 "major": "N"
#             },
#             {
#                 "name": "persons",
#                 "value": "McKenna, Aline Brosh",
#                 "rank": 5,
#                 "major": "N"
#             }
#         ],
#         "pub_date": "2023-02-10T00:00:05+0000",
#         "byline": {
#             "original": "By Amy Nicholson",
#             "person": [
#                 {
#                     "firstname": "Amy",
#                     "middlename": null,
#                     "lastname": "Nicholson",
#                     "qualifier": null,
#                     "title": null,
#                     "role": "reported",
#                     "organization": "",
#                     "rank": 1
#                 }
#             ],
#             "organization": null
#         },
#         "word_count": 569
#     },
#     {
#         "web_url": "https://www.nytimes.com/2023/02/02/movies/love-in-the-time-of-fentanyl-review.html",
#         "snippet": "To combat the overdose crisis, a group that includes former and current users open a safe consumption site where shooting up does not have to mean death.",
#         "source": "The New York Times",
#         "headline": {
#             "main": "\u2018Love in the Time of Fentanyl\u2019 Review: Heartbreak, Death and Hope in Vancouver",
#             "kicker": null,
#             "content_kicker": null,
#             "print_headline": "Love in the Time Of Fentanyl",
#             "name": null,
#             "seo": null,
#             "sub": null
#         },
#         "keywords": [
#             {
#                 "name": "subject",
#                 "value": "Documentary Films and Programs",
#                 "rank": 1,
#                 "major": "N"
#             },
#             {
#                 "name": "subject",
#                 "value": "Fentanyl",
#                 "rank": 2,
#                 "major": "N"
#             },
#             {
#                 "name": "subject",
#                 "value": "Drug Abuse and Traffic",
#                 "rank": 3,
#                 "major": "N"
#             },
#             {
#                 "name": "subject",
#                 "value": "Volunteers and Community Service",
#                 "rank": 4,
#                 "major": "N"
#             },
#             {
#                 "name": "creative_works",
#                 "value": "Love in the Time of Fentanyl (Movie)",
#                 "rank": 5,
#                 "major": "N"
#             },
#             {
#                 "name": "persons",
#                 "value": "Askey, Colin",
#                 "rank": 6,
#                 "major": "N"
#             },
#             {
#                 "name": "glocations",
#                 "value": "Vancouver (British Columbia)",
#                 "rank": 7,
#                 "major": "N"
#             },
#             {
#                 "name": "organizations",
#                 "value": "Overdose Prevention Society",
#                 "rank": 8,
#                 "major": "N"
#             }
#         ],
#         "pub_date": "2023-02-02T12:00:11+0000",
#         "byline": {
#             "original": "By Concepci\u00f3n de Le\u00f3n",
#             "person": [
#                 {
#                     "firstname": "Concepci\u00f3n",
#                     "middlename": null,
#                     "lastname": "de Le\u00f3n",
#                     "qualifier": null,
#                     "title": null,
#                     "role": "reported",
#                     "organization": "",
#                     "rank": 1
#                 }
#             ],
#             "organization": null
#         },
#         "word_count": 306
#     },
#     {
#         "web_url": "https://www.nytimes.com/2023/01/31/movies/pamela-a-love-story-review.html",
#         "snippet": "This documentary from Ryan White rewinds, to powerful effect, on Pamela Anderson\u2019s life and fame.",
#         "source": "The New York Times",
#         "headline": {
#             "main": "\u2018Pamela, a Love Story\u2019 Review: A Frank Look Back",
#             "kicker": null,
#             "content_kicker": null,
#             "print_headline": "Pamela, a Love Story",
#             "name": null,
#             "seo": null,
#             "sub": null
#         },
#         "keywords": [
#             {
#                 "name": "subject",
#                 "value": "Documentary Films and Programs",
#                 "rank": 1,
#                 "major": "N"
#             },
#             {
#                 "name": "persons",
#                 "value": "Anderson, Pamela (1967- )",
#                 "rank": 2,
#                 "major": "N"
#             },
#             {
#                 "name": "persons",
#                 "value": "White, Ryan (Filmmaker)",
#                 "rank": 3,
#                 "major": "N"
#             },
#             {
#                 "name": "creative_works",
#                 "value": "Pamela, a Love Story (Movie)",
#                 "rank": 4,
#                 "major": "N"
#             }
#         ],
#         "pub_date": "2023-01-31T12:00:05+0000",
#         "byline": {
#             "original": "By Glenn Kenny",
#             "person": [
#                 {
#                     "firstname": "Glenn",
#                     "middlename": null,
#                     "lastname": "Kenny",
#                     "qualifier": null,
#                     "title": null,
#                     "role": "reported",
#                     "organization": "",
#                     "rank": 1
#                 }
#             ],
#             "organization": null
#         },
#         "word_count": 295
#     },
#     {
#         "web_url": "https://www.nytimes.com/2023/01/19/movies/in-from-the-side-review.html",
#         "snippet": "In Matt Carter\u2019s gay rugby film, sports and romance smash together like two players from opposing teams.",
#         "source": "The New York Times",
#         "headline": {
#             "main": "\u2018In From the Side\u2019 Review: Love and Rugby Play a Losing Game",
#             "kicker": null,
#             "content_kicker": null,
#             "print_headline": "In From the Side",
#             "name": null,
#             "seo": null,
#             "sub": null
#         },
#         "keywords": [
#             {
#                 "name": "subject",
#                 "value": "Movies",
#                 "rank": 1,
#                 "major": "N"
#             },
#             {
#                 "name": "creative_works",
#                 "value": "In From the Side (Movie)",
#                 "rank": 2,
#                 "major": "N"
#             },
#             {
#                 "name": "persons",
#                 "value": "Carter, Matt (Filmmaker)",
#                 "rank": 3,
#                 "major": "N"
#             }
#         ],
#         "pub_date": "2023-01-19T17:50:16+0000",
#         "byline": {
#             "original": "By Kyle Turner",
#             "person": [
#                 {
#                     "firstname": "Kyle",
#                     "middlename": null,
#                     "lastname": "Turner",
#                     "qualifier": null,
#                     "title": null,
#                     "role": "reported",
#                     "organization": "",
#                     "rank": 1
#                 }
#             ],
#             "organization": null
#         },
#         "word_count": 281
#     },
#     {
#         "web_url": "https://www.nytimes.com/2023/01/19/movies/after-love-review.html",
#         "snippet": "In this intelligent melodrama by the director Aleem Khan, a British woman discovers her husband has been leading a double life.",
#         "source": "The New York Times",
#         "headline": {
#             "main": "\u2018After Love\u2019 Review: The Other Woman",
#             "kicker": "Critic\u2019s Pick",
#             "content_kicker": null,
#             "print_headline": "After Love",
#             "name": null,
#             "seo": null,
#             "sub": null
#         },
#         "keywords": [
#             {
#                 "name": "subject",
#                 "value": "Movies",
#                 "rank": 1,
#                 "major": "N"
#             },
#             {
#                 "name": "creative_works",
#                 "value": "After Love (2020) (Movie)",
#                 "rank": 2,
#                 "major": "N"
#             },
#             {
#                 "name": "persons",
#                 "value": "Khan, Aleem",
#                 "rank": 3,
#                 "major": "N"
#             },
#             {
#                 "name": "persons",
#                 "value": "Scanlan, Joanna (1961- )",
#                 "rank": 4,
#                 "major": "N"
#             }
#         ],
#         "pub_date": "2023-01-19T12:00:06+0000",
#         "byline": {
#             "original": "By Beatrice Loayza",
#             "person": [
#                 {
#                     "firstname": "Beatrice",
#                     "middlename": null,
#                     "lastname": "Loayza",
#                     "qualifier": null,
#                     "title": null,
#                     "role": "reported",
#                     "organization": "",
#                     "rank": 1
#                 }
#             ],
#             "organization": null
#         },
#         "word_count": 359
#     },
#     {
#         "web_url": "https://www.nytimes.com/2023/01/05/movies/alcarras-review.html",
#         "snippet": "In this naturalistic drama from Spain, a family confronts the impending loss of its generations-old farm.",
#         "source": "The New York Times",
#         "headline": {
#             "main": "\u2018Alcarr\u00e0s\u2019 Review: Labor of Love",
#             "kicker": null,
#             "content_kicker": null,
#             "print_headline": "Alcarr\u00e0s",
#             "name": null,
#             "seo": null,
#             "sub": null
#         },
#         "keywords": [
#             {
#                 "name": "subject",
#                 "value": "Movies",
#                 "rank": 1,
#                 "major": "N"
#             },
#             {
#                 "name": "persons",
#                 "value": "Simon, Carla",
#                 "rank": 2,
#                 "major": "N"
#             },
#             {
#                 "name": "creative_works",
#                 "value": "Alcarras (Movie)",
#                 "rank": 3,
#                 "major": "N"
#             }
#         ],
#         "pub_date": "2023-01-05T12:00:03+0000",
#         "byline": {
#             "original": "By Devika Girish",
#             "person": [
#                 {
#                     "firstname": "Devika",
#                     "middlename": null,
#                     "lastname": "Girish",
#                     "qualifier": null,
#                     "title": null,
#                     "role": "reported",
#                     "organization": "",
#                     "rank": 1
#                 }
#             ],
#             "organization": null
#         },
#         "word_count": 306
#     },
#     {
#         "web_url": "https://www.nytimes.com/2022/12/15/movies/nelly-and-nadine-review.html",
#         "snippet": "A family archive provides intimate records of a love affair that began between two women imprisoned in the Ravensbr\u00fcck concentration camp.",
#         "source": "The New York Times",
#         "headline": {
#             "main": "\u2018Nelly & Nadine\u2019 Review: An Unlikely Love, an Unlikely Record",
#             "kicker": null,
#             "content_kicker": null,
#             "print_headline": "Nelly &amp; Nadine",
#             "name": null,
#             "seo": null,
#             "sub": null
#         },
#         "keywords": [
#             {
#                 "name": "subject",
#                 "value": "Documentary Films and Programs",
#                 "rank": 1,
#                 "major": "N"
#             },
#             {
#                 "name": "persons",
#                 "value": "Gertten, Magnus",
#                 "rank": 2,
#                 "major": "N"
#             },
#             {
#                 "name": "creative_works",
#                 "value": "Nelly & Nadine (Movie)",
#                 "rank": 3,
#                 "major": "N"
#             },
#             {
#                 "name": "subject",
#                 "value": "Content Type: Personal Profile",
#                 "rank": 4,
#                 "major": "N"
#             },
#             {
#                 "name": "subject",
#                 "value": "Holocaust and the Nazi Era",
#                 "rank": 5,
#                 "major": "N"
#             },
#             {
#                 "name": "subject",
#                 "value": "World War II (1939-45)",
#                 "rank": 6,
#                 "major": "N"
#             },
#             {
#                 "name": "subject",
#                 "value": "Women and Girls",
#                 "rank": 7,
#                 "major": "N"
#             },
#             {
#                 "name": "subject",
#                 "value": "Homosexuality and Bisexuality",
#                 "rank": 8,
#                 "major": "N"
#             }
#         ],
#         "pub_date": "2022-12-15T12:00:04+0000",
#         "byline": {
#             "original": "By Teo Bugbee",
#             "person": [
#                 {
#                     "firstname": "Teo",
#                     "middlename": null,
#                     "lastname": "Bugbee",
#                     "qualifier": null,
#                     "title": null,
#                     "role": "reported",
#                     "organization": "",
#                     "rank": 1
#                 }
#             ],
#             "organization": null
#         },
#         "word_count": 308
#     },
#     {
#         "web_url": "https://www.nytimes.com/2022/12/01/movies/lady-chatterleys-lover-review.html",
#         "snippet": "The new Netflix adaptation of D.H. Lawrence\u2019s once-controversial novel is both steamy and decorous.",
#         "source": "The New York Times",
#         "headline": {
#             "main": "\u2018Lady Chatterley\u2019s Lover\u2019 Review: When Connie Met Ollie",
#             "kicker": null,
#             "content_kicker": null,
#             "print_headline": "A Love Whose Name Is Often Spoken",
#             "name": null,
#             "seo": null,
#             "sub": null
#         },
#         "keywords": [
#             {
#                 "name": "subject",
#                 "value": "Movies",
#                 "rank": 1,
#                 "major": "N"
#             },
#             {
#                 "name": "creative_works",
#                 "value": "Lady Chatterley's Lover (Movie)",
#                 "rank": 2,
#                 "major": "N"
#             },
#             {
#                 "name": "persons",
#                 "value": "Corrin, Emma (1995- )",
#                 "rank": 3,
#                 "major": "N"
#             },
#             {
#                 "name": "persons",
#                 "value": "De Clermont-Tonnerre, Laure",
#                 "rank": 4,
#                 "major": "N"
#             },
#             {
#                 "name": "persons",
#                 "value": "Lawrence, D H",
#                 "rank": 5,
#                 "major": "N"
#             }
#         ],
#         "pub_date": "2022-12-01T16:40:55+0000",
#         "byline": {
#             "original": "By A.O. Scott",
#             "person": [
#                 {
#                     "firstname": "A.",
#                     "middlename": "O.",
#                     "lastname": "Scott",
#                     "qualifier": null,
#                     "title": null,
#                     "role": "reported",
#                     "organization": "",
#                     "rank": 1
#                 }
#             ],
#             "organization": null
#         },
#         "word_count": 768
#     },
#     {
#         "web_url": "https://www.nytimes.com/2022/11/23/movies/sound-of-christmas-review.html",
#         "snippet": "A young singer gets more than she bargained for when she accepts a job as a nanny for a billionaire\u2019s children.",
#         "source": "The New York Times",
#         "headline": {
#             "main": "\u2018The Sound of Christmas\u2019 Review: A Gospel Singer Finds Love",
#             "kicker": null,
#             "content_kicker": null,
#             "print_headline": "The Sound  Of Christmas",
#             "name": null,
#             "seo": null,
#             "sub": null
#         },
#         "keywords": [
#             {
#                 "name": "subject",
#                 "value": "Movies",
#                 "rank": 1,
#                 "major": "N"
#             },
#             {
#                 "name": "persons",
#                 "value": "Ne-Yo",
#                 "rank": 2,
#                 "major": "N"
#             },
#             {
#                 "name": "creative_works",
#                 "value": "The Sound of Christmas (Movie)",
#                 "rank": 3,
#                 "major": "N"
#             },
#             {
#                 "name": "persons",
#                 "value": "Mattison, Booker T",
#                 "rank": 4,
#                 "major": "N"
#             },
#             {
#                 "name": "persons",
#                 "value": "McNeill, Serayah",
#                 "rank": 5,
#                 "major": "N"
#             }
#         ],
#         "pub_date": "2022-11-23T15:00:09+0000",
#         "byline": {
#             "original": "By Concepci\u00f3n de Le\u00f3n",
#             "person": [
#                 {
#                     "firstname": "Concepci\u00f3n",
#                     "middlename": null,
#                     "lastname": "de Le\u00f3n",
#                     "qualifier": null,
#                     "title": null,
#                     "role": "reported",
#                     "organization": "",
#                     "rank": 1
#                 }
#             ],
#             "organization": null
#         },
#         "word_count": 277
#     },
#     {
#         "web_url": "https://www.nytimes.com/2022/11/17/movies/the-inspection-review-boot-camp-a-love-story.html",
#         "snippet": "Elegance Bratton\u2019s autobiographical first feature is a lyrical, wrenching look at a young Marine\u2019s journey through basic training.",
#         "source": "The New York Times",
#         "headline": {
#             "main": "\u2018The Inspection\u2019 Review: Boot Camp, a Love Story",
#             "kicker": "critic\u2019s pick",
#             "content_kicker": null,
#             "print_headline": "A Few Good Men, Some With Secrets",
#             "name": null,
#             "seo": null,
#             "sub": null
#         },
#         "keywords": [
#             {
#                 "name": "subject",
#                 "value": "Movies",
#                 "rank": 1,
#                 "major": "N"
#             },
#             {
#                 "name": "creative_works",
#                 "value": "The Inspection (Movie)",
#                 "rank": 2,
#                 "major": "N"
#             },
#             {
#                 "name": "persons",
#                 "value": "Bratton, Elegance",
#                 "rank": 3,
#                 "major": "N"
#             }
#         ],
#         "pub_date": "2022-11-17T12:00:07+0000",
#         "byline": {
#             "original": "By A.O. Scott",
#             "person": [
#                 {
#                     "firstname": "A.",
#                     "middlename": "O.",
#                     "lastname": "Scott",
#                     "qualifier": null,
#                     "title": null,
#                     "role": "reported",
#                     "organization": "",
#                     "rank": 1
#                 }
#             ],
#             "organization": null
#         },
#         "word_count": 836
#     },
#     {
#         "web_url": "https://www.nytimes.com/2022/11/17/movies/bones-and-all-review.html",
#         "snippet": "Luca Guadagnino\u2019s latest stars Timoth\u00e9e Chalamet and Taylor Russell as young cannibals on the run.",
#         "source": "The New York Times",
#         "headline": {
#             "main": "\u2018Bones and All\u2019 Review: You Eat What You Are",
#             "kicker": null,
#             "content_kicker": null,
#             "print_headline": "It\u2019s Eat, Prey, Love on a Journey of Self-Discovery",
#             "name": null,
#             "seo": null,
#             "sub": null
#         },
#         "keywords": [
#             {
#                 "name": "subject",
#                 "value": "Movies",
#                 "rank": 1,
#                 "major": "N"
#             },
#             {
#                 "name": "creative_works",
#                 "value": "Bones and All (Movie)",
#                 "rank": 2,
#                 "major": "N"
#             },
#             {
#                 "name": "persons",
#                 "value": "Guadagnino, Luca",
#                 "rank": 3,
#                 "major": "N"
#             },
#             {
#                 "name": "persons",
#                 "value": "Chalamet, Timothee (1995- )",
#                 "rank": 4,
#                 "major": "N"
#             },
#             {
#                 "name": "persons",
#                 "value": "Russell, Taylor (1994- )",
#                 "rank": 5,
#                 "major": "N"
#             }
#         ],
#         "pub_date": "2022-11-17T12:00:06+0000",
#         "byline": {
#             "original": "By A.O. Scott",
#             "person": [
#                 {
#                     "firstname": "A.",
#                     "middlename": "O.",
#                     "lastname": "Scott",
#                     "qualifier": null,
#                     "title": null,
#                     "role": "reported",
#                     "organization": "",
#                     "rank": 1
#                 }
#             ],
#             "organization": null
#         },
#         "word_count": 710
#     },
#     {
#         "web_url": "https://www.nytimes.com/2022/10/20/movies/my-policeman-review.html",
# ...
#         },
#         "keywords": [
#             {
#                 "name": "subject",
#                 "value": "Movies",
#                 "rank": 1,
#                 "major": "N"
#             },
#             {
#                 "name": "creative_works",
#                 "value": "The Happiest Day in the Life of Olli Maki (Movie)",
#                 "rank": 2,
#                 "major": "N"
#             },
#             {
#                 "name": "persons",
#                 "value": "Kuosmanen, Juho",
#                 "rank": 3,
#                 "major": "N"
#             },
#             {
#                 "name": "persons",
#                 "value": "Lahti, Jarkko",
#                 "rank": 4,
#                 "major": "N"
#             }
#         ],
#         "pub_date": "2017-04-20T20:45:54+0000",
#         "byline": {
#             "original": "By Manohla Dargis",
#             "person": [
#                 {
#                     "firstname": "Manohla",
#                     "middlename": null,
#                     "lastname": "Dargis",
#                     "qualifier": null,
#                     "title": null,
#                     "role": "reported",
#                     "organization": "",
#                     "rank": 1
#                 }
#             ],
#             "organization": null
#         },
#         "word_count": 824
#     },
#     {
#         "web_url": "https://www.nytimes.com/2017/04/20/movies/the-promise-review-oscar-isaac.html",
#         "snippet": "Oscar Isaac, Christian Bale and Charlotte Le Bon star in this wartime romance with a heavy subject (genocide) but a corny plot.",
#         "source": "The New York Times",
#         "headline": {
#             "main": "Review: \u2018The Promise\u2019 Finds a Love Triangle in Constantinople",
#             "kicker": null,
#             "content_kicker": null,
#             "print_headline": "A Love Triangle, Near the Front Lines",
#             "name": null,
#             "seo": null,
#             "sub": null
#         },
#         "keywords": [
#             {
#                 "name": "subject",
#                 "value": "Movies",
#                 "rank": 1,
#                 "major": "N"
#             },
#             {
#                 "name": "creative_works",
#                 "value": "The Promise (Movie)",
#                 "rank": 2,
#                 "major": "N"
#             },
#             {
#                 "name": "persons",
#                 "value": "George, Terry",
#                 "rank": 3,
#                 "major": "N"
#             },
#             {
#                 "name": "persons",
#                 "value": "Bale, Christian",
#                 "rank": 4,
#                 "major": "N"
#             },
#             {
#                 "name": "persons",
#                 "value": "Isaac, Oscar",
#                 "rank": 5,
#                 "major": "N"
#             },
#             {
#                 "name": "persons",
#                 "value": "Le Bon, Charlotte",
#                 "rank": 6,
#                 "major": "N"
#             }
#         ],
#         "pub_date": "2017-04-20T16:49:46+0000",
#         "byline": {
#             "original": "By Jeannette Catsoulis",
#             "person": [
#                 {
#                     "firstname": "Jeannette",
#                     "middlename": null,
#                     "lastname": "Catsoulis",
#                     "qualifier": null,
#                     "title": null,
#                     "role": "reported",
#                     "organization": "",
#                     "rank": 1
#                 }
#             ],
#             "organization": null
#         },
#         "word_count": 455
#     },
#     {
#         "web_url": "https://www.nytimes.com/2017/03/14/movies/frantz-review.html",
#         "snippet": "Fran\u00e7ois Ozon\u2019s adaptation of Ernst Lubitsch\u2019s 1932 antiwar film, \u201cBroken Lullaby,\u201d is set in Germany and France in the aftermath of World War I.",
#         "source": "The New York Times",
#         "headline": {
#             "main": "Review: \u2018Frantz,\u2019 a Mysterious Frenchman and the Wounds of War",
#             "kicker": null,
#             "content_kicker": null,
#             "print_headline": "The Wounds of War and Love",
#             "name": null,
#             "seo": null,
#             "sub": null
#         },
#         "keywords": [
#             {
#                 "name": "creative_works",
#                 "value": "Frantz (Movie)",
#                 "rank": 1,
#                 "major": "N"
#             },
#             {
#                 "name": "persons",
#                 "value": "Niney, Pierre",
#                 "rank": 2,
#                 "major": "N"
#             },
#             {
#                 "name": "subject",
#                 "value": "Movies",
#                 "rank": 3,
#                 "major": "N"
#             },
#             {
#                 "name": "persons",
#                 "value": "Lubitsch, Ernst",
#                 "rank": 4,
#                 "major": "N"
#             },
#             {
#                 "name": "persons",
#                 "value": "Ozon, Francois",
#                 "rank": 5,
#                 "major": "N"
#             }
#         ],
#         "pub_date": "2017-03-14T21:14:24+0000",
#         "byline": {
#             "original": "By Stephen Holden",
#             "person": [
#                 {
#                     "firstname": "Stephen",
#                     "middlename": null,
#                     "lastname": "Holden",
#                     "qualifier": null,
#                     "title": null,
#                     "role": "reported",
#                     "organization": "",
#                     "rank": 1
#                 }
#             ],
#             "organization": null
#         },
#         "word_count": 708
#     },
#     {
#         "web_url": "https://www.nytimes.com/2017/03/09/movies/the-other-half-review-tatiana-maslany.html",
#         "snippet": "This moody romance stars Tatiana Maslany (\u201cOrphan Black\u201d) as a bipolar painter in love with a brooding cabby (Tom Cullen of \u201cDownton Abbey\u201d).",
#         "source": "The New York Times",
#         "headline": {
#             "main": "Review: A Combustible Pair Find Love in \u2018The Other Half\u2019",
#             "kicker": null,
#             "content_kicker": null,
#             "print_headline": "Review: A Combustible Pair Find Love in \u2018The Other Half\u2019",
#             "name": null,
#             "seo": null,
#             "sub": null
#         },
#         "keywords": [
#             {
#                 "name": "subject",
#                 "value": "Movies",
#                 "rank": 1,
#                 "major": "N"
#             },
#             {
#                 "name": "creative_works",
#                 "value": "The Other Half (Movie)",
#                 "rank": 2,
#                 "major": "N"
#             },
#             {
#                 "name": "persons",
#                 "value": "Maslany, Tatiana",
#                 "rank": 3,
#                 "major": "N"
#             },
#             {
#                 "name": "persons",
#                 "value": "Cullen, Tom (1985- )",
#                 "rank": 4,
#                 "major": "N"
#             },
#             {
#                 "name": "persons",
#                 "value": "Klein, Joey (Film Director)",
#                 "rank": 5,
#                 "major": "N"
#             }
#         ],
#         "pub_date": "2017-03-09T21:54:58+0000",
#         "byline": {
#             "original": "By Andy Webster",
#             "person": [
#                 {
#                     "firstname": "Andy",
#                     "middlename": null,
#                     "lastname": "Webster",
#                     "qualifier": null,
#                     "title": null,
#                     "role": "reported",
#                     "organization": "",
#                     "rank": 1
#                 }
#             ],
#             "organization": null
#         },
#         "word_count": 251
#     },
#     {
#         "web_url": "https://www.nytimes.com/2017/03/09/movies/review-the-ottoman-lieutenant.html",
#         "snippet": "A nurse travels to the Ottoman Empire on the eve of World War I. Can romance blossom amid earthshaking events?",
#         "source": "The New York Times",
#         "headline": {
#             "main": "Review: Love as the World Wars, in \u2018The Ottoman Lieutenant\u2019",
#             "kicker": null,
#             "content_kicker": null,
#             "print_headline": "Review: Love as the World Wars, in \u2018The Ottoman Lieutenant\u2019",
#             "name": null,
#             "seo": null,
#             "sub": null
#         },
#         "keywords": [
#             {
#                 "name": "subject",
#                 "value": "Movies",
#                 "rank": 1,
#                 "major": "N"
#             },
#             {
#                 "name": "creative_works",
#                 "value": "The Ottoman Lieutenant (Movie)",
#                 "rank": 2,
#                 "major": "N"
#             },
#             {
#                 "name": "persons",
#                 "value": "Ruben, Joseph",
#                 "rank": 3,
#                 "major": "N"
#             },
#             {
#                 "name": "persons",
#                 "value": "Hartnett, Josh",
#                 "rank": 4,
#                 "major": "N"
#             },
#             {
#                 "name": "persons",
#                 "value": "Stockwell, Jeff (1958- )",
#                 "rank": 5,
#                 "major": "N"
#             },
#             {
#                 "name": "persons",
#                 "value": "Hilmar, Hera",
#                 "rank": 6,
#                 "major": "N"
#             },
#             {
#                 "name": "persons",
#                 "value": "Huisman, Michiel",
#                 "rank": 7,
#                 "major": "N"
#             }
#         ],
#         "pub_date": "2017-03-09T21:53:12+0000",
#         "byline": {
#             "original": "By Neil Genzlinger",
#             "person": [
#                 {
#                     "firstname": "Neil",
#                     "middlename": null,
#                     "lastname": "Genzlinger",
#                     "qualifier": null,
#                     "title": null,
#                     "role": "reported",
#                     "organization": "",
#                     "rank": 1
#                 }
#             ],
#             "organization": null
#         },
#         "word_count": 267
#     },
#     {
#         "web_url": "https://www.nytimes.com/2017/03/02/movies/love-taxes-review.html",
#         "snippet": "Josh Kornbluth runs afoul of the Internal Revenue Service after failing to file tax returns for seven years.",
#         "source": "The New York Times",
#         "headline": {
#             "main": "Review: It\u2019s All Mirth and Taxes in \u2018Love & Taxes\u2019",
#             "kicker": null,
#             "content_kicker": null,
#             "print_headline": "It\u2019s Inevitable, Mirth and Taxes",
#             "name": null,
#             "seo": null,
#             "sub": null
#         },
#         "keywords": [
#             {
#                 "name": "creative_works",
#                 "value": "Love & Taxes (Movie)",
#                 "rank": 1,
#                 "major": "N"
#             },
#             {
#                 "name": "persons",
#                 "value": "Kornbluth, Jacob",
#                 "rank": 2,
#                 "major": "N"
#             },
#             {
#                 "name": "subject",
#                 "value": "Movies",
#                 "rank": 3,
#                 "major": "N"
#             },
#             {
#                 "name": "persons",
#                 "value": "Kornbluth, Josh",
#                 "rank": 4,
#                 "major": "N"
#             }
#         ],
#         "pub_date": "2017-03-02T21:44:18+0000",
#         "byline": {
#             "original": "By Ken Jaworowski",
#             "person": [
#                 {
#                     "firstname": "Ken",
#                     "middlename": null,
#                     "lastname": "Jaworowski",
#                     "qualifier": null,
#                     "title": null,
#                     "role": "reported",
#                     "organization": "",
#                     "rank": 1
#                 }
#             ],
#             "organization": null
#         },
#         "word_count": 246
#     },
#     {
#         "web_url": "https://www.nytimes.com/2017/02/16/movies/everybody-loves-somebody-review.html",
#         "snippet": "A messed-up heroine is asked to choose between naughty and nice in Catalina Aguilar Mastretta\u2019s sophomore feature, which is predictable but satisfying.",
#         "source": "The New York Times",
#         "headline": {
#             "main": "Review: \u2018Everybody Loves Somebody,\u2019 a Rom-Com With Bite",
#             "kicker": null,
#             "content_kicker": null,
#             "print_headline": "Everybody Loves Somebody",
#             "name": null,
#             "seo": null,
#             "sub": null
#         },
#         "keywords": [
#             {
#                 "name": "subject",
#                 "value": "Movies",
#                 "rank": 1,
#                 "major": "N"
#             },
#             {
#                 "name": "creative_works",
#                 "value": "Everybody Loves Somebody (Movie)",
#                 "rank": 2,
#                 "major": "N"
#             },
#             {
#                 "name": "persons",
#                 "value": "Aguilar Mastretta, Catalina",
#                 "rank": 3,
#                 "major": "N"
#             },
#             {
#                 "name": "persons",
#                 "value": "Souza, Karla (1985- )",
#                 "rank": 4,
#                 "major": "N"
#             }
#         ],
#         "pub_date": "2017-02-16T21:45:50+0000",
#         "byline": {
#             "original": "By Jeannette Catsoulis",
#             "person": [
#                 {
#                     "firstname": "Jeannette",
#                     "middlename": null,
#                     "lastname": "Catsoulis",
#                     "qualifier": null,
#                     "title": null,
#                     "role": "reported",
#                     "organization": "",
#                     "rank": 1
#                 }
#             ],
#             "organization": null
#         },
#         "word_count": 256
#     },
#     {
#         "web_url": "https://www.nytimes.com/2017/02/09/movies/kedi-review.html",
#         "snippet": "This documentary profiles distinctive street cats in Istanbul and the human communities that interact with them.",
#         "source": "The New York Times",
#         "headline": {
#             "main": "Review: Cute Cats of \u2018Kedi,\u2019 Rekindling a \u2018Love of Life\u2019",
#             "kicker": null,
#             "content_kicker": null,
#             "print_headline": "Kedi",
#             "name": null,
#             "seo": null,
#             "sub": null
#         },
#         "keywords": [
#             {
#                 "name": "creative_works",
#                 "value": "Kedi (Movie)",
#                 "rank": 1,
#                 "major": "N"
#             },
#             {
#                 "name": "subject",
#                 "value": "Documentary Films and Programs",
#                 "rank": 2,
#                 "major": "N"
#             },
#             {
#                 "name": "subject",
#                 "value": "Cats",
#                 "rank": 3,
#                 "major": "N"
#             },
#             {
#                 "name": "glocations",
#                 "value": "Istanbul (Turkey)",
#                 "rank": 4,
#                 "major": "N"
#             },
#             {
#                 "name": "persons",
#                 "value": "Torun, Ceyda",
#                 "rank": 5,
#                 "major": "N"
#             }
#         ],
#         "pub_date": "2017-02-09T16:21:39+0000",
#         "byline": {
#             "original": "By Glenn Kenny",
#             "person": [
#                 {
#                     "firstname": "Glenn",
#                     "middlename": null,
#                     "lastname": "Kenny",
#                     "qualifier": null,
#                     "title": null,
#                     "role": "reported",
#                     "organization": "",
#                     "rank": 1
#                 }
#             ],
#             "organization": null
#         },
#         "word_count": 274
#     }
# ]

# %%
# Convert reviews_list to a Pandas DataFrame using json_normalize()
reviews_df = pd.json_normalize(reviews_list)
reviews_df.head()
# Out:
#                                              web_url  \
# 0  https://www.nytimes.com/2023/05/25/movies/the-...
# 1  https://www.nytimes.com/2023/05/04/movies/what...
# 2  https://www.nytimes.com/2023/05/04/movies/you-...
# 3  https://www.nytimes.com/2023/04/21/movies/a-to...
# 4  https://www.nytimes.com/2023/04/20/movies/othe...
#
#                                              snippet              source  \
# 0  A gynecologist and her patient form a horrifyi...  The New York Times
# 1  Two childhood friends navigate cultural differ...  The New York Times
# 2  Religion comes between two girls falling in lo...  The New York Times
# 3  Rachael Leigh Cook stars in this bland rom-com...  The New York Times
# 4  A radiant Virginie Efira stars as a Parisian t...  The New York Times
#
#                                             keywords  \
# 0  [{'name': 'subject', 'value': 'Movies', 'rank'...
# 1  [{'name': 'subject', 'value': 'Movies', 'rank'...
# 2  [{'name': 'subject', 'value': 'Movies', 'rank'...
# 3  [{'name': 'subject', 'value': 'Movies', 'rank'...
# 4  [{'name': 'subject', 'value': 'Movies', 'rank'...
#
#                    pub_date  word_count  \
# 0  2023-05-25T11:00:03+0000         295
# 1  2023-05-04T17:16:45+0000         287
# 2  2023-05-04T11:00:08+0000         294
# 3  2023-04-21T07:03:25+0000         276
# 4  2023-04-20T15:35:13+0000         801
#
#                                        headline.main headline.kicker  \
# 0        ‘The Attachment Diaries’ Review: Love, Sick            None
# 1  Review: ‘What’s Love Got to Do With It?’ Proba...            None
# 2  ‘You Can Live Forever’ Review: Do You Love Me ...            None
# 3  ‘A Tourist’s Guide to Love’ Review: A Wearying...            None
# 4     ‘Other People’s Children’ Review: True Romance   Critic’s pick
#
#   headline.content_kicker                 headline.print_headline  \
# 0                    None                  The Attachment Diaries
# 1                    None          What’s Love Got to Do With It?
# 2                    None                    You Can Live Forever
# 3                    None              A Tourist’s  Guide to Love
# 4                    None  Intoxicating Love With a Sobering Turn
#
#   headline.name headline.seo headline.sub           byline.original  \
# 0          None         None         None    By Jeannette Catsoulis
# 1          None         None         None    By Jeannette Catsoulis
# 2          None         None         None  By Elisabeth Vincentelli
# 3          None         None         None  By Elisabeth Vincentelli
# 4          None         None         None         By Manohla Dargis
#
#                                        byline.person byline.organization
# 0  [{'firstname': 'Jeannette', 'middlename': None...                None
# 1  [{'firstname': 'Jeannette', 'middlename': None...                None
# 2  [{'firstname': 'Elisabeth', 'middlename': None...                None
# 3  [{'firstname': 'Elisabeth', 'middlename': None...                None
# 4  [{'firstname': 'Manohla', 'middlename': None, ...                None

# %%
# Extract the title from the "headline.main" column and
# save it to a new column "title"
# Title is between unicode characters \u2018 and \u2019. 
# End string should include " Review" to avoid cutting title early
reviews_df["title"] = reviews_df["headline.main"].apply(lambda st: st[st.find("\u2018")+1:st.find("\u2019 Review")])

reviews_df.head()
# Out:
#                                              web_url  \
# 0  https://www.nytimes.com/2023/05/25/movies/the-...
# 1  https://www.nytimes.com/2023/05/04/movies/what...
# 2  https://www.nytimes.com/2023/05/04/movies/you-...
# 3  https://www.nytimes.com/2023/04/21/movies/a-to...
# 4  https://www.nytimes.com/2023/04/20/movies/othe...
#
#                                              snippet              source  \
# 0  A gynecologist and her patient form a horrifyi...  The New York Times
# 1  Two childhood friends navigate cultural differ...  The New York Times
# 2  Religion comes between two girls falling in lo...  The New York Times
# 3  Rachael Leigh Cook stars in this bland rom-com...  The New York Times
# 4  A radiant Virginie Efira stars as a Parisian t...  The New York Times
#
#                                             keywords  \
# 0  [{'name': 'subject', 'value': 'Movies', 'rank'...
# 1  [{'name': 'subject', 'value': 'Movies', 'rank'...
# 2  [{'name': 'subject', 'value': 'Movies', 'rank'...
# 3  [{'name': 'subject', 'value': 'Movies', 'rank'...
# 4  [{'name': 'subject', 'value': 'Movies', 'rank'...
#
#                    pub_date  word_count  \
# 0  2023-05-25T11:00:03+0000         295
# 1  2023-05-04T17:16:45+0000         287
# 2  2023-05-04T11:00:08+0000         294
# 3  2023-04-21T07:03:25+0000         276
# 4  2023-04-20T15:35:13+0000         801
#
#                                        headline.main headline.kicker  \
# 0        ‘The Attachment Diaries’ Review: Love, Sick            None
# 1  Review: ‘What’s Love Got to Do With It?’ Proba...            None
# 2  ‘You Can Live Forever’ Review: Do You Love Me ...            None
# 3  ‘A Tourist’s Guide to Love’ Review: A Wearying...            None
# 4     ‘Other People’s Children’ Review: True Romance   Critic’s pick
#
#   headline.content_kicker                 headline.print_headline  \
# 0                    None                  The Attachment Diaries
# 1                    None          What’s Love Got to Do With It?
# 2                    None                    You Can Live Forever
# 3                    None              A Tourist’s  Guide to Love
# 4                    None  Intoxicating Love With a Sobering Turn
#
#   headline.name headline.seo headline.sub           byline.original  \
# 0          None         None         None    By Jeannette Catsoulis
# 1          None         None         None    By Jeannette Catsoulis
# 2          None         None         None  By Elisabeth Vincentelli
# 3          None         None         None  By Elisabeth Vincentelli
# 4          None         None         None         By Manohla Dargis
#
#                                        byline.person byline.organization  \
# 0  [{'firstname': 'Jeannette', 'middlename': None...                None
# 1  [{'firstname': 'Jeannette', 'middlename': None...                None
# 2  [{'firstname': 'Elisabeth', 'middlename': None...                None
# 3  [{'firstname': 'Elisabeth', 'middlename': None...                None
# 4  [{'firstname': 'Manohla', 'middlename': None, ...                None
#
#                                            title
# 0                         The Attachment Diaries
# 1  What’s Love Got to Do With It?’ Probably a Lo
# 2                           You Can Live Forever
# 3                      A Tourist’s Guide to Love
# 4                        Other People’s Children

# %%
# Extract 'name' and 'value' from items in "keywords" column
def extract_keywords(keyword_list):
    extracted_keywords = ""
    for item in keyword_list:
        # Extract 'name' and 'value'
        keyword = f"{item['name']}: {item['value']};" 
        # Append the keyword item to the extracted_keywords list
        extracted_keywords += keyword
    return extracted_keywords

# Fix the "keywords" column by converting cells from a list to a string
reviews_df["keywords"] = reviews_df["keywords"].apply(extract_keywords)
reviews_df.head()
# Out:
#                                              web_url  \
# 0  https://www.nytimes.com/2023/05/25/movies/the-...
# 1  https://www.nytimes.com/2023/05/04/movies/what...
# 2  https://www.nytimes.com/2023/05/04/movies/you-...
# 3  https://www.nytimes.com/2023/04/21/movies/a-to...
# 4  https://www.nytimes.com/2023/04/20/movies/othe...
#
#                                              snippet              source  \
# 0  A gynecologist and her patient form a horrifyi...  The New York Times
# 1  Two childhood friends navigate cultural differ...  The New York Times
# 2  Religion comes between two girls falling in lo...  The New York Times
# 3  Rachael Leigh Cook stars in this bland rom-com...  The New York Times
# 4  A radiant Virginie Efira stars as a Parisian t...  The New York Times
#
#                                             keywords  \
# 0  subject: Movies;creative_works: The Attachment...
# 1  subject: Movies;persons: Kapur, Shekhar;person...
# 2  subject: Movies;creative_works: You Can Live F...
# 3  subject: Movies;creative_works: A Tourist's Gu...
# 4  subject: Movies;persons: Zlotowski, Rebecca;cr...
#
#                    pub_date  word_count  \
# 0  2023-05-25T11:00:03+0000         295
# 1  2023-05-04T17:16:45+0000         287
# 2  2023-05-04T11:00:08+0000         294
# 3  2023-04-21T07:03:25+0000         276
# 4  2023-04-20T15:35:13+0000         801
#
#                                        headline.main headline.kicker  \
# 0        ‘The Attachment Diaries’ Review: Love, Sick            None
# 1  Review: ‘What’s Love Got to Do With It?’ Proba...            None
# 2  ‘You Can Live Forever’ Review: Do You Love Me ...            None
# 3  ‘A Tourist’s Guide to Love’ Review: A Wearying...            None
# 4     ‘Other People’s Children’ Review: True Romance   Critic’s pick
#
#   headline.content_kicker                 headline.print_headline  \
# 0                    None                  The Attachment Diaries
# 1                    None          What’s Love Got to Do With It?
# 2                    None                    You Can Live Forever
# 3                    None              A Tourist’s  Guide to Love
# 4                    None  Intoxicating Love With a Sobering Turn
#
#   headline.name headline.seo headline.sub           byline.original  \
# 0          None         None         None    By Jeannette Catsoulis
# 1          None         None         None    By Jeannette Catsoulis
# 2          None         None         None  By Elisabeth Vincentelli
# 3          None         None         None  By Elisabeth Vincentelli
# 4          None         None         None         By Manohla Dargis
#
#                                        byline.person byline.organization  \
# 0  [{'firstname': 'Jeannette', 'middlename': None...                None
# 1  [{'firstname': 'Jeannette', 'middlename': None...                None
# 2  [{'firstname': 'Elisabeth', 'middlename': None...                None
# 3  [{'firstname': 'Elisabeth', 'middlename': None...                None
# 4  [{'firstname': 'Manohla', 'middlename': None, ...                None
#
#                                            title
# 0                         The Attachment Diaries
# 1  What’s Love Got to Do With It?’ Probably a Lo
# 2                           You Can Live Forever
# 3                      A Tourist’s Guide to Love
# 4                        Other People’s Children

# %%
reviews_df.columns
# Out:
# Index(['web_url', 'snippet', 'source', 'keywords', 'pub_date', 'word_count',
#        'headline.main', 'headline.kicker', 'headline.content_kicker',
#        'headline.print_headline', 'headline.name', 'headline.seo',
#        'headline.sub', 'byline.original', 'byline.person',
#        'byline.organization', 'title'],
#       dtype='object')

# %%
# Create a list from the "title" column using to_list()
# These titles will be used in the query for The Movie Database
for title in reviews_df["title"].to_list():
    print(title)
# Out:
# The Attachment Diaries
# What’s Love Got to Do With It?’ Probably a Lo
# You Can Live Forever
# A Tourist’s Guide to Love
# Other People’s Children
# One True Loves
# The Lost Weekend: A Love Story
# A Thousand and One
# Your Place or Mine
# Love in the Time of Fentanyl
# Pamela, a Love Story
# In From the Side
# After Love
# Alcarràs
# Nelly & Nadine
# Lady Chatterley’s Lover
# The Sound of Christmas
# The Inspection
# Bones and All
# My Policeman
# About Fate
# Waiting for Bojangles
# I Love My Dad
# A Love Song
# Alone Together
# Art of Love
# The Wheel
# Thor: Love and Thunder
# Both Sides of the Blade
# Fire of Love
# Love & Gelato
# Stay Prayed Up
# Benediction
# Dinner in America
# In a New York Minute
# Anaïs in Love
# I Love America
# See You Then
# La Mami
# Love After Love
# Deep Water
# Lucy and Desi
# Cyrano
# The In Between
# Book of Love
# Lingui, the Sacred Bonds
# The Pink Cloud
# A Journal for Jordan
# West Side Story
# Aulcie
# Love Is Love Is Love
# Love Hard
# Bergman Island
# Hard Luck Love Song
# South of Heaven
# Wife of a Spy
# Happier Than Ever
# Together
# Annette
# Resort to Love
# Woodstock 99: Peace, Love and Rage
# Casanova, Last Love
# Running Against the Wind
# Asia
# Undine
# This Town
# Tu Me Manques
# Monday
# Ride or Die
# Future People
# Luz
# Happily
# This Is the Life
# To All the Boys: Always and Forever
# Young Hearts
# Little Fish
# Two of Us
# Atlantis
# Preparations to Be Together
# Your Name Engraved Herein
# Sylvie’s Love
# Ariana Grande: Excuse Me, I Love You
# Museum Town
# Wild Mountain Thyme
# My Psychedelic Love Story
# 69: The Saga of Danny Hernandez
# Ammonite
# Love and Monsters
# Dick Johnson Is Dead
# Love, Guaranteed
# Feel the Beat
# Babyteeth
# Spelling the Dream
# A Secret Love
# Love Wedding Repeat
# Almost Love
# Hope Gap
# All the Bright Places
# The Photograph
# You Go to My Head
# Ordinary Love
# To All the Boys: P.S. I Still Love You
# The Woman Who Loves Giraffes
# Queen & Slim
# Marriage Story
# Cyrano, My Love
# Pretenders
# First Love
# Loro
# Falling Inn Love
# Hot Air
# Love, Antosha
# Leto
# The Tomorrow Man
# Asako I & II
# The Sun Is Also a Star
# Shéhérazade
# Long Shot
# Clara
# Kalank
# Rafiki
# Diane
# Five Feet Apart
# Ash Is Purest White
# Gloria Bell
# Black Mother
# The Hole in the Ground
# How to Train Your Dragon: The Hidden World
# A Tuba to Cuba
# Fighting With My Family
# Sorry Angel
# Berlin, I Love You
# Untogether
# Cold War
# If Beale Street Could Talk
# Asher
# The Party’s Just Beginning
# The Great Pretender
# Sicilian Ghost Story
# The New Romantic
# Pimp
# In a Relationship
# They’ll Love Me When I’m Dead’ Documents Orson Welles’s Last Fil
# Burning,’ Love Ignites a Divided Worl
# After Everything,’ a Young Love Blooms in Crisi
# Quincy’ Captures a Lifelong Love Affair With Musi
# Love, Gilda,’ a Portrait of a Brief and Brilliant Caree
# Tea With the Dames,’ Four Legends Dish on Acting and Lov
# Bel Canto,’ Music Is the Food of Love and Rebellio
# The Citizen,’ an Immigrant Picks a Bad Time to Fall in Lov
# Love, Cecil,’ an Aesthete Ahead of His Tim
# How to Talk to Girls at Parties
# Rogers Park,’ Life and Love in a Chicago Neighborhoo
# Love & Bananas,’ Uncovering the Plight of the Asian Elephan
# Godard Mon Amour
# Submergence,’ a Love Story Sunk by Geopolitic
# Love After Love,’ an Unflinching Look at Extended Grie
# Outside In
# Love, Simon,’ a Glossy Teen Romance, the Hero Has a Secre
# Keep the Change,’ Two People With Autism Find Lov
# The Party
# The Housemaid,’ Twisted Love and Angry Ghosts in Vietna
# Forever My Girl,’ a Romance Resumes After a Long Brea
# Kangaroo: A Love-Hate Story’ Exposes a Wildlife Massacr
# Lover for a Day
# Youth,’ the People’s Dance Troupe, in Love and Wa
# Killing for Love’ Revisits a Virginia Murder Cas
# The Shape of Water’ Is Altogether Wonderfu
# Love Beats Rhymes,’ a Hip-Hop Artist Transformed by Poetr
# Cuba and the Cameraman’ Lavishes Love on a Country … and Castr
# On the Beach at Night Alone’ Zooms in on a Love Affai
# Thelma,’ a Woman in Love Can Burn Down the Worl
# Hello Again,’ a Movie Musical Ode to Love and Lust Over Decade
# It Happened in L.A.,’ All That Questing After Lov
# God’s Own Country
# The Mountain Between Us
# Dina,’ a Differently Abled Love Stor
# In Search of Fellini
# Woodpeckers,’ a Tale of Love and Agonizing Penal Confinemen
# I Do ... Until I Don’t,’ Love and Loathing in Florid
# Tales of an Immoral Couple’: Love Means Having to Grow U
# After Love’ and Regretting Every Momen
# The Last Face
# Women Who Kill,’ and May Be in Love With On
# False Confessions,’ the Play’s Not Quite the Thin
# Review: Those Movies, Himself — Bertrand Tavernier’s Tour of French Cinem
# The Big Sick,’ Comedy Is Hard, Love Harde
# Lost in Paris
# Vincent N Roxxy,’ Love Is in the Air, N So Is Fea
# Everything, Everything’ Pits Love Against Diseas
# Hounds of Love’ Is Tense and Deadly Down Unde
# Harold and Lillian’ Introduces a Hollywood Power Coupl
# The Happiest Day in the Life of Olli Maki,’ Love and Life on the Rope
# The Promise’ Finds a Love Triangle in Constantinopl
# Frantz,’ a Mysterious Frenchman and the Wounds of Wa
# The Other Half
# The Ottoman Lieutenant
# Love & Taxes
# Everybody Loves Somebody,’ a Rom-Com With Bit
# Kedi,’ Rekindling a ‘Love of Life

# %% [markdown]
# ### Access The Movie Database API

# %%
### Access The Movie Database API
# Prepare The Movie Database query
url = "https://api.themoviedb.org/3/search/movie?query="
tmdb_key_string = "&api_key=" + tmdb_api_key

# %%
# Create an empty list to store the results
tmdb_movies_list = []

# Create a request counter to manage the rate limit
request_counter = 0

# Loop through the titles
for title in reviews_df["title"].to_list():
    # Check if we need to sleep before making a request
    if request_counter % 50 == 0 and request_counter != 0:
        time.sleep(10)
    # Add 1 to the request counter
    request_counter += 1

    # Perform a "GET" request for The Movie Database
    response = requests.get(url, params={'api_key': tmdb_api_key, 'query': title})

    # Include a try clause to search for the full movie details.
    # Use the except clause to print out a statement if a movie
    # is not found.
    if response.status_code != 200:
        print(f"Error fetching data for {title}: {response.status_code} - {response.text}")
        continue

    try:
        movie_data = response.json()
        if movie_data['results']:
            # Get movie ID
            movie_id = movie_data['results'][0]['id']
            # Make a request for the movie details
            movie_detail_url = f"https://api.themoviedb.org/3/movie/{movie_id}?api_key={tmdb_api_key}"
            details_response = requests.get(movie_detail_url)
            if details_response.status_code == 200:
                # Extract the details
                movie_details = details_response.json()

                # Extract genre names, spoken languages, and production countries
                genre_names = [genre['name'] for genre in movie_details.get('genres', [])]
                spoken_languages = [language['name'] for language in movie_details.get('spoken_languages', [])]
                production_countries = [country['name'] for country in movie_details.get('production_countries', [])]

                # Prepare the movie info dictionary
                movie_info = {
                    'title': title,
                    'genres': genre_names,
                    'languages': spoken_languages,
                    'countries': production_countries,  
                    'release_date': movie_details['release_date'],
                    'runtime': movie_details['runtime'],
                    'vote_average': movie_details['vote_average'],
                    'budget': movie_details['budget'],
                    'revenue': movie_details['revenue'],
                    'overview': movie_details['overview'],
                    'tagline': movie_details['tagline'],
                    'imdb_id': movie_details['imdb_id'],
                    'poster_path': movie_details['poster_path'],
                    'backdrop_path': movie_details['backdrop_path'],
                    'original_language': movie_details['original_language'],
                    'original_title': movie_details['original_title'],
                    'popularity': movie_details['popularity'],
                    'vote_count': movie_details['vote_count'],
                    'homepage': movie_details['homepage'],
                    'spoken_languages': movie_details['spoken_languages'],
                    'production_countries': movie_details['production_countries'],
                        
                }       

                # Append the movie info to the list
                tmdb_movies_list.append(movie_info)

                print(f"Found {title}")
            else:
                print(f"Details not found for {title}")
        else:
            print(f"No results for {title}")
    except Exception as e:
        print(f"Exception for {title}: {e}")

# Print the tmdb_movies_list
print(tmdb_movies_list)
# Out:
# Found The Attachment Diaries
# No results for What’s Love Got to Do With It?’ Probably a Lo
# Found You Can Live Forever
# Found A Tourist’s Guide to Love
# Found Other People’s Children
# Found One True Loves
# Found The Lost Weekend: A Love Story
# Found A Thousand and One
# Found Your Place or Mine
# Found Love in the Time of Fentanyl
# Found Pamela, a Love Story
# Found In From the Side
# Found After Love
# Found Alcarràs
# Found Nelly & Nadine
# Found Lady Chatterley’s Lover
# Found The Sound of Christmas
# Found The Inspection
# Found Bones and All
# Found My Policeman
# Found About Fate
# Found Waiting for Bojangles
# Found I Love My Dad
# Found A Love Song
# Found Alone Together
# Found Art of Love
# Found The Wheel
# Found Thor: Love and Thunder
# Found Both Sides of the Blade
# Found Fire of Love
# Found Love & Gelato
# Found Stay Prayed Up
# Found Benediction
# Found Dinner in America
# Found In a New York Minute
# Found Anaïs in Love
# Found I Love America
# Found See You Then
# Found La Mami
# Found Love After Love
# Found Deep Water
# Found Lucy and Desi
# Found Cyrano
# Found The In Between
# Found Book of Love
# Found Lingui, the Sacred Bonds
# Found The Pink Cloud
# Found A Journal for Jordan
# Found West Side Story
# No results for Aulcie
# Found Love Is Love Is Love
# Found Love Hard
# Found Bergman Island
# Found Hard Luck Love Song
# Found South of Heaven
# Found Wife of a Spy
# Found Happier Than Ever
# Found Together
# Found Annette
# Found Resort to Love
# Found Woodstock 99: Peace, Love and Rage
# Found Casanova, Last Love
# Found Running Against the Wind
# Found Asia
# Found Undine
# Found This Town
# Found Tu Me Manques
# Found Monday
# Found Ride or Die
# Found Future People
# Found Luz
# Found Happily
# Found This Is the Life
# Found To All the Boys: Always and Forever
# Found Young Hearts
# Found Little Fish
# Found Two of Us
# Found Atlantis
# Found Preparations to Be Together
# Found Your Name Engraved Herein
# Found Sylvie’s Love
# Found Ariana Grande: Excuse Me, I Love You
# Found Museum Town
# Found Wild Mountain Thyme
# Found My Psychedelic Love Story
# Found 69: The Saga of Danny Hernandez
# Found Ammonite
# Found Love and Monsters
# Found Dick Johnson Is Dead
# Found Love, Guaranteed
# Found Feel the Beat
# Found Babyteeth
# Found Spelling the Dream
# Found A Secret Love
# Found Love Wedding Repeat
# Found Almost Love
# Found Hope Gap
# Found All the Bright Places
# Found The Photograph
# Found You Go to My Head
# Found Ordinary Love
# Found To All the Boys: P.S. I Still Love You
# Found The Woman Who Loves Giraffes
# Found Queen & Slim
# Found Marriage Story
# Found Cyrano, My Love
# Found Pretenders
# Found First Love
# Found Loro
# Found Falling Inn Love
# Found Hot Air
# Found Love, Antosha
# Found Leto
# Found The Tomorrow Man
# Found Asako I & II
# Found The Sun Is Also a Star
# Found Shéhérazade
# Found Long Shot
# Found Clara
# Found Kalank
# Found Rafiki
# Found Diane
# Found Five Feet Apart
# Found Ash Is Purest White
# Found Gloria Bell
# Found Black Mother
# Found The Hole in the Ground
# Found How to Train Your Dragon: The Hidden World
# Found A Tuba to Cuba
# Found Fighting With My Family
# Found Sorry Angel
# Found Berlin, I Love You
# Found Untogether
# Found Cold War
# Found If Beale Street Could Talk
# Found Asher
# Found The Party’s Just Beginning
# Found The Great Pretender
# Found Sicilian Ghost Story
# Found The New Romantic
# Found Pimp
# Found In a Relationship
# No results for They’ll Love Me When I’m Dead’ Documents Orson Welles’s Last Fil
# No results for Burning,’ Love Ignites a Divided Worl
# No results for After Everything,’ a Young Love Blooms in Crisi
# No results for Quincy’ Captures a Lifelong Love Affair With Musi
# No results for Love, Gilda,’ a Portrait of a Brief and Brilliant Caree
# No results for Tea With the Dames,’ Four Legends Dish on Acting and Lov
# No results for Bel Canto,’ Music Is the Food of Love and Rebellio
# No results for The Citizen,’ an Immigrant Picks a Bad Time to Fall in Lov
# No results for Love, Cecil,’ an Aesthete Ahead of His Tim
# Found How to Talk to Girls at Parties
# No results for Rogers Park,’ Life and Love in a Chicago Neighborhoo
# No results for Love & Bananas,’ Uncovering the Plight of the Asian Elephan
# Found Godard Mon Amour
# No results for Submergence,’ a Love Story Sunk by Geopolitic
# No results for Love After Love,’ an Unflinching Look at Extended Grie
# Found Outside In
# No results for Love, Simon,’ a Glossy Teen Romance, the Hero Has a Secre
# No results for Keep the Change,’ Two People With Autism Find Lov
# Found The Party
# No results for The Housemaid,’ Twisted Love and Angry Ghosts in Vietna
# No results for Forever My Girl,’ a Romance Resumes After a Long Brea
# No results for Kangaroo: A Love-Hate Story’ Exposes a Wildlife Massacr
# Found Lover for a Day
# No results for Youth,’ the People’s Dance Troupe, in Love and Wa
# No results for Killing for Love’ Revisits a Virginia Murder Cas
# No results for The Shape of Water’ Is Altogether Wonderfu
# No results for Love Beats Rhymes,’ a Hip-Hop Artist Transformed by Poetr
# No results for Cuba and the Cameraman’ Lavishes Love on a Country … and Castr
# No results for On the Beach at Night Alone’ Zooms in on a Love Affai
# No results for Thelma,’ a Woman in Love Can Burn Down the Worl
# No results for Hello Again,’ a Movie Musical Ode to Love and Lust Over Decade
# No results for It Happened in L.A.,’ All That Questing After Lov
# Found God’s Own Country
# Found The Mountain Between Us
# No results for Dina,’ a Differently Abled Love Stor
# Found In Search of Fellini
# No results for Woodpeckers,’ a Tale of Love and Agonizing Penal Confinemen
# No results for I Do ... Until I Don’t,’ Love and Loathing in Florid
# No results for Tales of an Immoral Couple’: Love Means Having to Grow U
# No results for After Love’ and Regretting Every Momen
# Found The Last Face
# No results for Women Who Kill,’ and May Be in Love With On
# No results for False Confessions,’ the Play’s Not Quite the Thin
# No results for Review: Those Movies, Himself — Bertrand Tavernier’s Tour of French Cinem
# No results for The Big Sick,’ Comedy Is Hard, Love Harde
# Found Lost in Paris
# No results for Vincent N Roxxy,’ Love Is in the Air, N So Is Fea
# No results for Everything, Everything’ Pits Love Against Diseas
# No results for Hounds of Love’ Is Tense and Deadly Down Unde
# No results for Harold and Lillian’ Introduces a Hollywood Power Coupl
# No results for The Happiest Day in the Life of Olli Maki,’ Love and Life on the Rope
# No results for The Promise’ Finds a Love Triangle in Constantinopl
# No results for Frantz,’ a Mysterious Frenchman and the Wounds of Wa
# Found The Other Half
# Found The Ottoman Lieutenant
# Found Love & Taxes
# No results for Everybody Loves Somebody,’ a Rom-Com With Bit
# No results for Kedi,’ Rekindling a ‘Love of Life
# [{'title': 'The Attachment Diaries', 'genres': ['Drama', 'Mystery', 'Thriller', 'Horror'], 'languages': ['Español'], 'countries': ['Argentina'], 'release_date': '2021-10-07', 'runtime': 102, 'vote_average': 4.0, 'budget': 0, 'revenue': 0, 'overview': 'Argentina, 1970s. A desperate young woman goes to a clinic to have a clandestine abortion. As her pregnancy is already through the fourth month, the doctor refuses. Instead, she proposes to sell the baby to one of her clients and offers to provide shelter in her house until the child is born. Their disturbed personalities will become intertwined in a strange and dangerous relationship.', 'tagline': '', 'imdb_id': 'tt11359158', 'poster_path': '/hKZHk6I1p58ZeXbwjQok7DSWfZ.jpg', 'backdrop_path': None, 'original_language': 'es', 'original_title': 'El apego', 'popularity': 0.997, 'vote_count': 2, 'homepage': '', 'spoken_languages': [{'english_name': 'Spanish', 'iso_639_1': 'es', 'name': 'Español'}], 'production_countries': [{'iso_3166_1': 'AR', 'name': 'Argentina'}]}, {'title': 'You Can Live Forever', 'genres': ['Drama', 'Romance'], 'languages': ['English', 'Français'], 'countries': ['Canada', 'United States of America'], 'release_date': '2023-03-24', 'runtime': 96, 'vote_average': 6.8, 'budget': 0, 'revenue': 15055, 'overview': "When Jaime, a gay teenager, is sent to live in a community of Jehovah's Witnesses in small-town Quebec, she falls madly in love with a devout Witness girl. The two embark on an intense affair with consequences that will reshape the rest of their lives.", 'tagline': '', 'imdb_id': 'tt15782570', 'poster_path': '/10MJURrsPfDQmS2AP3fueOHJ0ch.jpg', 'backdrop_path': '/sClvKM8C6a1DSPzMwkKjk8pNFDx.jpg', 'original_language': 'en', 'original_title': 'You Can Live Forever', 'popularity': 5.922, 'vote_count': 28, 'homepage': 'https://gooddeedentertainment.com/you-can-live-forever/', 'spoken_languages': [{'english_name': 'English', 'iso_639_1': 'en', 'name': 'English'}, {'english_name': 'French', 'iso_639_1': 'fr', 'name': 'Français'}], 'production_countries': [{'iso_3166_1': 'CA', 'name': 'Canada'}, {'iso_3166_1': 'US', 'name': 'United States of America'}]}, {'title': 'A Tourist’s Guide to Love', 'genres': ['Romance', 'Comedy'], 'languages': ['English', 'Tiếng Việt'], 'countries': ['United States of America'], 'release_date': '2023-04-21', 'runtime': 96, 'vote_average': 6.365, 'budget': 0, 'revenue': 0, 'overview': 'After an unexpected break up, a travel executive accepts an assignment to go undercover and learn about the tourist industry in Vietnam. Along the way, she finds adventure and romance with her Vietnamese expat tour guide and they decide to hijack the tour bus in order to explore life and love off the beaten path.', 'tagline': '', 'imdb_id': 'tt20115096', 'poster_path': '/uWkpjbBe4gRZilXRXbYfsMUZMhz.jpg', 'backdrop_path': '/z3Qc5a0grcCREAQKqI195P05dVf.jpg', 'original_language': 'en', 'original_title': "A Tourist's Guide to Love", 'popularity': 23.381, 'vote_count': 144, 'homepage': 'https://www.netflix.com/title/81424906', 'spoken_languages': [{'english_name': 'English', 'iso_639_1': 'en', 'name': 'English'}, {'english_name': 'Vietnamese', 'iso_639_1': 'vi', 'name': 'Tiếng Việt'}], 'production_countries': [{'iso_3166_1': 'US', 'name': 'United States of America'}]}, {'title': 'Other People’s Children', 'genres': ['Drama', 'Comedy'], 'languages': ['English', 'Français'], 'countries': ['France'], 'release_date': '2022-09-21', 'runtime': 104, 'vote_average': 6.9, 'budget': 0, 'revenue': 84178, 'overview': 'Rachel loves her life, her students, her friends, her ex, her guitar lessons. When she falls in love with Ali, she grows close to his 4-year-old daughter, Leila. She tucks her in, looks after her, and loves her like a mother... which she isn’t. Not yet. Rachel is 40. The desire for a family of her own is growing stronger, and the clock is ticking. Is it too late?', 'tagline': '', 'imdb_id': 'tt15403712', 'poster_path': '/4vsQ4894pzd7nbvP5FoSOHaS1mI.jpg', 'backdr ...

# %%
# Preview the first 5 results in JSON format
# Use json.dumps with argument indent=4 to format data
import json
num_movies_to_preview = min(5, len(tmdb_movies_list))
for movie in tmdb_movies_list[:num_movies_to_preview]:
    print(json.dumps(movie, indent=4))
    print()
# Out:
# {
#     "title": "The Attachment Diaries",
#     "genres": [
#         "Drama",
#         "Mystery",
#         "Thriller",
#         "Horror"
#     ],
#     "languages": [
#         "Espa\u00f1ol"
#     ],
#     "countries": [
#         "Argentina"
#     ],
#     "release_date": "2021-10-07",
#     "runtime": 102,
#     "vote_average": 4.0,
#     "budget": 0,
#     "revenue": 0,
#     "overview": "Argentina, 1970s. A desperate young woman goes to a clinic to have a clandestine abortion. As her pregnancy is already through the fourth month, the doctor refuses. Instead, she proposes to sell the baby to one of her clients and offers to provide shelter in her house until the child is born. Their disturbed personalities will become intertwined in a strange and dangerous relationship.",
#     "tagline": "",
#     "imdb_id": "tt11359158",
#     "poster_path": "/hKZHk6I1p58ZeXbwjQok7DSWfZ.jpg",
#     "backdrop_path": null,
#     "original_language": "es",
#     "original_title": "El apego",
#     "popularity": 0.997,
#     "vote_count": 2,
#     "homepage": "",
#     "spoken_languages": [
#         {
#             "english_name": "Spanish",
#             "iso_639_1": "es",
#             "name": "Espa\u00f1ol"
#         }
#     ],
#     "production_countries": [
#         {
#             "iso_3166_1": "AR",
#             "name": "Argentina"
#         }
#     ]
# }
#
# {
#     "title": "You Can Live Forever",
#     "genres": [
#         "Drama",
#         "Romance"
#     ],
#     "languages": [
#         "English",
#         "Fran\u00e7ais"
#     ],
#     "countries": [
#         "Canada",
#         "United States of America"
#     ],
#     "release_date": "2023-03-24",
#     "runtime": 96,
#     "vote_average": 6.8,
#     "budget": 0,
#     "revenue": 15055,
#     "overview": "When Jaime, a gay teenager, is sent to live in a community of Jehovah's Witnesses in small-town Quebec, she falls madly in love with a devout Witness girl. The two embark on an intense affair with consequences that will reshape the rest of their lives.",
#     "tagline": "",
#     "imdb_id": "tt15782570",
#     "poster_path": "/10MJURrsPfDQmS2AP3fueOHJ0ch.jpg",
#     "backdrop_path": "/sClvKM8C6a1DSPzMwkKjk8pNFDx.jpg",
#     "original_language": "en",
#     "original_title": "You Can Live Forever",
#     "popularity": 5.922,
#     "vote_count": 28,
#     "homepage": "https://gooddeedentertainment.com/you-can-live-forever/",
#     "spoken_languages": [
#         {
#             "english_name": "English",
#             "iso_639_1": "en",
#             "name": "English"
#         },
#         {
#             "english_name": "French",
#             "iso_639_1": "fr",
#             "name": "Fran\u00e7ais"
#         }
#     ],
#     "production_countries": [
#         {
#             "iso_3166_1": "CA",
#             "name": "Canada"
#         },
#         {
#             "iso_3166_1": "US",
#             "name": "United States of America"
#         }
#     ]
# }
#
# {
#     "title": "A Tourist\u2019s Guide to Love",
#     "genres": [
#         "Romance",
#         "Comedy"
#     ],
#     "languages": [
#         "English",
#         "Ti\u1ebfng Vi\u1ec7t"
#     ],
#     "countries": [
#         "United States of America"
#     ],
#     "release_date": "2023-04-21",
#     "runtime": 96,
#     "vote_average": 6.365,
#     "budget": 0,
#     "revenue": 0,
#     "overview": "After an unexpected break up, a travel executive accepts an assignment to go undercover and learn about the tourist industry in Vietnam. Along the way, she finds adventure and romance with her Vietnamese expat tour guide and they decide to hijack the tour bus in order to explore life and love off the beaten path.",
#     "tagline": "",
#     "imdb_id": "tt20115096",
#     "poster_path": "/uWkpjbBe4gRZilXRXbYfsMUZMhz.jpg",
#     "backdrop_path": "/z3Qc5a0grcCREAQKqI195P05dVf.jpg",
#     "original_language": "en",
#     "original_title": "A Tourist's Guide to Love",
#     "popularity": 23.381,
#     "vote_count": 144,
#     "homepage": "https://www.netflix.com/title/81424906",
#     "spoken_languages": [
#         {
#             "english_name": "English",
#             "iso_639_1": "en",
#             "name": "English"
#         },
#         {
#             "english_name": "Vietnamese",
#             "iso_639_1": "vi",
#             "name": "Ti\u1ebfng Vi\u1ec7t"
#         }
#     ],
#     "production_countries": [
#         {
#             "iso_3166_1": "US",
#             "name": "United States of America"
#         }
#     ]
# }
#
# {
#     "title": "Other People\u2019s Children",
#     "genres": [
#         "Drama",
#         "Comedy"
#     ],
#     "languages": [
#         "English",
#         "Fran\u00e7ais"
#     ],
#     "countries": [
#         "France"
#     ],
#     "release_date": "2022-09-21",
#     "runtime": 104,
#     "vote_average": 6.9,
#     "budget": 0,
#     "revenue": 84178,
#     "overview": "Rachel loves her life, her students, her friends, her ex, her guitar lessons. When she falls in love with Ali, she grows close to his 4-year-old daughter, Leila. She tucks her in, looks after her, and loves her like a mother... which she isn\u2019t. Not yet. Rachel is 40. The desire for a family of her own is growing stronger, and the clock is ticking. Is it too late?",
#     "tagline": "",
#     "imdb_id": "tt15403712",
#     "poster_path": "/4vsQ4894pzd7nbvP5FoSOHaS1mI.jpg",
#     "backdrop_path": "/33UGFiijBDX18NHecj5xz5GkkHt.jpg",
#     "original_language": "fr",
#     "original_title": "Les Enfants des autres",
#     "popularity": 13.638,
#     "vote_count": 169,
#     "homepage": "https://www.wildbunch.biz/movie/other-peoples-children/",
#     "spoken_languages": [
#         {
#             "english_name": "English",
#             "iso_639_1": "en",
#             "name": "English"
#         },
#         {
#             "english_name": "French",
#             "iso_639_1": "fr",
#             "name": "Fran\u00e7ais"
#         }
#     ],
#     "production_countries": [
#         {
#             "iso_3166_1": "FR",
#             "name": "France"
#         }
#     ]
# }
#
# {
#     "title": "One True Loves",
#     "genres": [
#         "Romance",
#         "Drama",
#         "Comedy"
#     ],
#     "languages": [
#         "English"
#     ],
#     "countries": [
#         "Germany",
#         "United States of America"
#     ],
#     "release_date": "2023-04-07",
#     "runtime": 100,
#     "vote_average": 6.669,
#     "budget": 0,
#     "revenue": 37820,
#     "overview": "Emma and Jesse are living the perfect life together, until Jesse disappears in a tragic helicopter crash on their first wedding anniversary. Four years later, Emma has found happiness again and is about to marry her best friend when Jesse resurfaces, turning her world upside down and leaving her torn between two great loves.",
#     "tagline": "First love meets new love.",
#     "imdb_id": "tt14770620",
#     "poster_path": "/6MF3JvIZkluUijw9rvDKNqPT8kC.jpg",
#     "backdrop_path": "/omkxkjj0IEhzOc9CBOwK2lrmHSk.jpg",
#     "original_language": "en",
#     "original_title": "One True Loves",
#     "popularity": 17.637,
#     "vote_count": 59,
#     "homepage": "",
#     "spoken_languages": [
#         {
#             "english_name": "English",
#             "iso_639_1": "en",
#             "name": "English"
#         }
#     ],
#     "production_countries": [
#         {
#             "iso_3166_1": "DE",
#             "name": "Germany"
#         },
#         {
#             "iso_3166_1": "US",
#             "name": "United States of America"
#         }
#     ]
# }

# %%
# Convert the results to a DataFrame
tmdb_movies_df = pd.DataFrame(tmdb_movies_list) 
tmdb_movies_df.head()
# Out:
#                        title                              genres  \
# 0     The Attachment Diaries  [Drama, Mystery, Thriller, Horror]
# 1       You Can Live Forever                    [Drama, Romance]
# 2  A Tourist’s Guide to Love                   [Romance, Comedy]
# 3    Other People’s Children                     [Drama, Comedy]
# 4             One True Loves            [Romance, Drama, Comedy]
#
#                languages                            countries release_date  \
# 0              [Español]                          [Argentina]   2021-10-07
# 1    [English, Français]   [Canada, United States of America]   2023-03-24
# 2  [English, Tiếng Việt]           [United States of America]   2023-04-21
# 3    [English, Français]                             [France]   2022-09-21
# 4              [English]  [Germany, United States of America]   2023-04-07
#
#    runtime  vote_average  budget  revenue  \
# 0      102         4.000       0        0
# 1       96         6.800       0    15055
# 2       96         6.365       0        0
# 3      104         6.900       0    84178
# 4      100         6.669       0    37820
#
#                                             overview  ...     imdb_id  \
# 0  Argentina, 1970s. A desperate young woman goes...  ...  tt11359158
# 1  When Jaime, a gay teenager, is sent to live in...  ...  tt15782570
# 2  After an unexpected break up, a travel executi...  ...  tt20115096
# 3  Rachel loves her life, her students, her frien...  ...  tt15403712
# 4  Emma and Jesse are living the perfect life tog...  ...  tt14770620
#
#                         poster_path                     backdrop_path  \
# 0   /hKZHk6I1p58ZeXbwjQok7DSWfZ.jpg                              None
# 1  /10MJURrsPfDQmS2AP3fueOHJ0ch.jpg  /sClvKM8C6a1DSPzMwkKjk8pNFDx.jpg
# 2  /uWkpjbBe4gRZilXRXbYfsMUZMhz.jpg  /z3Qc5a0grcCREAQKqI195P05dVf.jpg
# 3  /4vsQ4894pzd7nbvP5FoSOHaS1mI.jpg  /33UGFiijBDX18NHecj5xz5GkkHt.jpg
# 4  /6MF3JvIZkluUijw9rvDKNqPT8kC.jpg  /omkxkjj0IEhzOc9CBOwK2lrmHSk.jpg
#
#   original_language             original_title popularity  vote_count  \
# 0                es                   El apego      0.997           2
# 1                en       You Can Live Forever      5.922          28
# 2                en  A Tourist's Guide to Love     23.381         144
# 3                fr     Les Enfants des autres     13.638         169
# 4                en             One True Loves     17.637          59
#
#                                             homepage  \
# 0
# 1  https://gooddeedentertainment.com/you-can-live...
# 2             https://www.netflix.com/title/81424906
# 3  https://www.wildbunch.biz/movie/other-peoples-...
# 4
#
#                                     spoken_languages  \
# 0  [{'english_name': 'Spanish', 'iso_639_1': 'es'...
# 1  [{'english_name': 'English', 'iso_639_1': 'en'...
# 2  [{'english_name': 'English', 'iso_639_1': 'en'...
# 3  [{'english_name': 'English', 'iso_639_1': 'en'...
# 4  [{'english_name': 'English', 'iso_639_1': 'en'...
#
#                                 production_countries
# 0        [{'iso_3166_1': 'AR', 'name': 'Argentina'}]
# 1  [{'iso_3166_1': 'CA', 'name': 'Canada'}, {'iso...
# 2  [{'iso_3166_1': 'US', 'name': 'United States o...
# 3           [{'iso_3166_1': 'FR', 'name': 'France'}]
# 4  [{'iso_3166_1': 'DE', 'name': 'Germany'}, {'is...
#
# [5 rows x 21 columns]

# %% [markdown]
# ### Merge and Clean the Data for Export

# %%
# Merge the New York Times reviews and TMDB DataFrames on title
# Use an inner join to keep only the movies that are in both DataFrames
merged_df = pd.merge(reviews_df, tmdb_movies_df, on="title", how="inner")
merged_df.head()
# Out:
#                                              web_url  \
# 0  https://www.nytimes.com/2023/05/25/movies/the-...
# 1  https://www.nytimes.com/2023/05/04/movies/you-...
# 2  https://www.nytimes.com/2023/04/21/movies/a-to...
# 3  https://www.nytimes.com/2023/04/20/movies/othe...
# 4  https://www.nytimes.com/2023/04/13/movies/one-...
#
#                                              snippet              source  \
# 0  A gynecologist and her patient form a horrifyi...  The New York Times
# 1  Religion comes between two girls falling in lo...  The New York Times
# 2  Rachael Leigh Cook stars in this bland rom-com...  The New York Times
# 3  A radiant Virginie Efira stars as a Parisian t...  The New York Times
# 4  A film adaptation of Taylor Jenkins Reid’s nov...  The New York Times
#
#                                             keywords  \
# 0  subject: Movies;creative_works: The Attachment...
# 1  subject: Movies;creative_works: You Can Live F...
# 2  subject: Movies;creative_works: A Tourist's Gu...
# 3  subject: Movies;persons: Zlotowski, Rebecca;cr...
# 4  subject: Movies;persons: Bracey, Luke (1989- )...
#
#                    pub_date  word_count  \
# 0  2023-05-25T11:00:03+0000         295
# 1  2023-05-04T11:00:08+0000         294
# 2  2023-04-21T07:03:25+0000         276
# 3  2023-04-20T15:35:13+0000         801
# 4  2023-04-13T11:00:06+0000         320
#
#                                        headline.main headline.kicker  \
# 0        ‘The Attachment Diaries’ Review: Love, Sick            None
# 1  ‘You Can Live Forever’ Review: Do You Love Me ...            None
# 2  ‘A Tourist’s Guide to Love’ Review: A Wearying...            None
# 3     ‘Other People’s Children’ Review: True Romance   Critic’s pick
# 4     ‘One True Loves’ Review: A Romance Lost at Sea            None
#
#   headline.content_kicker                 headline.print_headline  ...  \
# 0                    None                  The Attachment Diaries  ...
# 1                    None                    You Can Live Forever  ...
# 2                    None              A Tourist’s  Guide to Love  ...
# 3                    None  Intoxicating Love With a Sobering Turn  ...
# 4                    None                          One True Loves  ...
#
#       imdb_id                       poster_path  \
# 0  tt11359158   /hKZHk6I1p58ZeXbwjQok7DSWfZ.jpg
# 1  tt15782570  /10MJURrsPfDQmS2AP3fueOHJ0ch.jpg
# 2  tt20115096  /uWkpjbBe4gRZilXRXbYfsMUZMhz.jpg
# 3  tt15403712  /4vsQ4894pzd7nbvP5FoSOHaS1mI.jpg
# 4  tt14770620  /6MF3JvIZkluUijw9rvDKNqPT8kC.jpg
#
#                       backdrop_path original_language  \
# 0                              None                es
# 1  /sClvKM8C6a1DSPzMwkKjk8pNFDx.jpg                en
# 2  /z3Qc5a0grcCREAQKqI195P05dVf.jpg                en
# 3  /33UGFiijBDX18NHecj5xz5GkkHt.jpg                fr
# 4  /omkxkjj0IEhzOc9CBOwK2lrmHSk.jpg                en
#
#               original_title popularity vote_count  \
# 0                   El apego      0.997          2
# 1       You Can Live Forever      5.922         28
# 2  A Tourist's Guide to Love     23.381        144
# 3     Les Enfants des autres     13.638        169
# 4             One True Loves     17.637         59
#
#                                             homepage  \
# 0
# 1  https://gooddeedentertainment.com/you-can-live...
# 2             https://www.netflix.com/title/81424906
# 3  https://www.wildbunch.biz/movie/other-peoples-...
# 4
#
#                                     spoken_languages  \
# 0  [{'english_name': 'Spanish', 'iso_639_1': 'es'...
# 1  [{'english_name': 'English', 'iso_639_1': 'en'...
# 2  [{'english_name': 'English', 'iso_639_1': 'en'...
# 3  [{'english_name': 'English', 'iso_639_1': 'en'...
# 4  [{'english_name': 'English', 'iso_639_1': 'en'...
#
#                                 production_countries
# 0        [{'iso_3166_1': 'AR', 'name': 'Argentina'}]
# 1  [{'iso_3166_1': 'CA', 'name': 'Canada'}, {'iso...
# 2  [{'iso_3166_1': 'US', 'name': 'United States o...
# 3           [{'iso_3166_1': 'FR', 'name': 'France'}]
# 4  [{'iso_3166_1': 'DE', 'name': 'Germany'}, {'is...
#
# [5 rows x 37 columns]

# %%
# Remove list brackets and quotation marks on the columns containing lists
# Create a list of the columns that need fixing
columns_to_fix = ["genres", "languages", "countries", "production_companies", "production_countries", "spoken_languages", "keywords", "cast", "crew",   "belongs_to_collection", "production_companies", "production_countries", "spoken_languages", "keywords", "cast", "crew", "belongs_to_collection"]

# Create a list of characters to remove
characters_to_remove = ["[", "]", "'", '"', "{", "}", "name", ":", "id","'"]
                        

# Loop through the list of columns to fix
for column in columns_to_fix:
    if column in tmdb_movies_df.columns:
    # Loop through the list of characters to remove for tmdb_movies_df
        for character in characters_to_remove:
        # Remove the character from tmdb_movies_df
            tmdb_movies_df[column] = tmdb_movies_df[column].astype(str).str.replace(character, "")

    # Loop through the list of characters to remove for reviews_df
    if column in reviews_df.columns:
        for character in characters_to_remove:
        # Remove the character from reviews_df
            reviews_df[column] = reviews_df[column].astype(str).str.replace(character, "")

# Display the fixed DataFrame
tmdb_movies_df.head()
# Out:
#                        title                            genres  \
# 0     The Attachment Diaries  Drama, Mystery, Thriller, Horror
# 1       You Can Live Forever                    Drama, Romance
# 2  A Tourist’s Guide to Love                   Romance, Comedy
# 3    Other People’s Children                     Drama, Comedy
# 4             One True Loves            Romance, Drama, Comedy
#
#              languages                          countries release_date  \
# 0              Español                          Argentina   2021-10-07
# 1    English, Français   Canada, United States of America   2023-03-24
# 2  English, Tiếng Việt           United States of America   2023-04-21
# 3    English, Français                             France   2022-09-21
# 4              English  Germany, United States of America   2023-04-07
#
#    runtime  vote_average  budget  revenue  \
# 0      102         4.000       0        0
# 1       96         6.800       0    15055
# 2       96         6.365       0        0
# 3      104         6.900       0    84178
# 4      100         6.669       0    37820
#
#                                             overview  ...     imdb_id  \
# 0  Argentina, 1970s. A desperate young woman goes...  ...  tt11359158
# 1  When Jaime, a gay teenager, is sent to live in...  ...  tt15782570
# 2  After an unexpected break up, a travel executi...  ...  tt20115096
# 3  Rachel loves her life, her students, her frien...  ...  tt15403712
# 4  Emma and Jesse are living the perfect life tog...  ...  tt14770620
#
#                         poster_path                     backdrop_path  \
# 0   /hKZHk6I1p58ZeXbwjQok7DSWfZ.jpg                              None
# 1  /10MJURrsPfDQmS2AP3fueOHJ0ch.jpg  /sClvKM8C6a1DSPzMwkKjk8pNFDx.jpg
# 2  /uWkpjbBe4gRZilXRXbYfsMUZMhz.jpg  /z3Qc5a0grcCREAQKqI195P05dVf.jpg
# 3  /4vsQ4894pzd7nbvP5FoSOHaS1mI.jpg  /33UGFiijBDX18NHecj5xz5GkkHt.jpg
# 4  /6MF3JvIZkluUijw9rvDKNqPT8kC.jpg  /omkxkjj0IEhzOc9CBOwK2lrmHSk.jpg
#
#   original_language             original_title popularity  vote_count  \
# 0                es                   El apego      0.997           2
# 1                en       You Can Live Forever      5.922          28
# 2                en  A Tourist's Guide to Love     23.381         144
# 3                fr     Les Enfants des autres     13.638         169
# 4                en             One True Loves     17.637          59
#
#                                             homepage  \
# 0
# 1  https://gooddeedentertainment.com/you-can-live...
# 2             https://www.netflix.com/title/81424906
# 3  https://www.wildbunch.biz/movie/other-peoples-...
# 4
#
#                                     spoken_languages  \
# 0           english_ Spanish, iso_639_1 es,  Español
# 1  english_ English, iso_639_1 en,  English, engl...
# 2  english_ English, iso_639_1 en,  English, engl...
# 3  english_ English, iso_639_1 en,  English, engl...
# 4           english_ English, iso_639_1 en,  English
#
#                                 production_countries
# 0                          iso_3166_1 AR,  Argentina
# 1  iso_3166_1 CA,  Canada, iso_3166_1 US,  United...
# 2           iso_3166_1 US,  United States of America
# 3                             iso_3166_1 FR,  France
# 4  iso_3166_1 DE,  Germany, iso_3166_1 US,  Unite...
#
# [5 rows x 21 columns]

# %%
# Drop "byline.person" column
merged_df = merged_df.drop(columns=["byline.person"])
merged_df.head()
# Out:
#                                              web_url  \
# 0  https://www.nytimes.com/2023/05/25/movies/the-...
# 1  https://www.nytimes.com/2023/05/04/movies/you-...
# 2  https://www.nytimes.com/2023/04/21/movies/a-to...
# 3  https://www.nytimes.com/2023/04/20/movies/othe...
# 4  https://www.nytimes.com/2023/04/13/movies/one-...
#
#                                              snippet              source  \
# 0  A gynecologist and her patient form a horrifyi...  The New York Times
# 1  Religion comes between two girls falling in lo...  The New York Times
# 2  Rachael Leigh Cook stars in this bland rom-com...  The New York Times
# 3  A radiant Virginie Efira stars as a Parisian t...  The New York Times
# 4  A film adaptation of Taylor Jenkins Reid’s nov...  The New York Times
#
#                                             keywords  \
# 0  subject: Movies;creative_works: The Attachment...
# 1  subject: Movies;creative_works: You Can Live F...
# 2  subject: Movies;creative_works: A Tourist's Gu...
# 3  subject: Movies;persons: Zlotowski, Rebecca;cr...
# 4  subject: Movies;persons: Bracey, Luke (1989- )...
#
#                    pub_date  word_count  \
# 0  2023-05-25T11:00:03+0000         295
# 1  2023-05-04T11:00:08+0000         294
# 2  2023-04-21T07:03:25+0000         276
# 3  2023-04-20T15:35:13+0000         801
# 4  2023-04-13T11:00:06+0000         320
#
#                                        headline.main headline.kicker  \
# 0        ‘The Attachment Diaries’ Review: Love, Sick            None
# 1  ‘You Can Live Forever’ Review: Do You Love Me ...            None
# 2  ‘A Tourist’s Guide to Love’ Review: A Wearying...            None
# 3     ‘Other People’s Children’ Review: True Romance   Critic’s pick
# 4     ‘One True Loves’ Review: A Romance Lost at Sea            None
#
#   headline.content_kicker                 headline.print_headline  ...  \
# 0                    None                  The Attachment Diaries  ...
# 1                    None                    You Can Live Forever  ...
# 2                    None              A Tourist’s  Guide to Love  ...
# 3                    None  Intoxicating Love With a Sobering Turn  ...
# 4                    None                          One True Loves  ...
#
#       imdb_id                       poster_path  \
# 0  tt11359158   /hKZHk6I1p58ZeXbwjQok7DSWfZ.jpg
# 1  tt15782570  /10MJURrsPfDQmS2AP3fueOHJ0ch.jpg
# 2  tt20115096  /uWkpjbBe4gRZilXRXbYfsMUZMhz.jpg
# 3  tt15403712  /4vsQ4894pzd7nbvP5FoSOHaS1mI.jpg
# 4  tt14770620  /6MF3JvIZkluUijw9rvDKNqPT8kC.jpg
#
#                       backdrop_path original_language  \
# 0                              None                es
# 1  /sClvKM8C6a1DSPzMwkKjk8pNFDx.jpg                en
# 2  /z3Qc5a0grcCREAQKqI195P05dVf.jpg                en
# 3  /33UGFiijBDX18NHecj5xz5GkkHt.jpg                fr
# 4  /omkxkjj0IEhzOc9CBOwK2lrmHSk.jpg                en
#
#               original_title popularity vote_count  \
# 0                   El apego      0.997          2
# 1       You Can Live Forever      5.922         28
# 2  A Tourist's Guide to Love     23.381        144
# 3     Les Enfants des autres     13.638        169
# 4             One True Loves     17.637         59
#
#                                             homepage  \
# 0
# 1  https://gooddeedentertainment.com/you-can-live...
# 2             https://www.netflix.com/title/81424906
# 3  https://www.wildbunch.biz/movie/other-peoples-...
# 4
#
#                                     spoken_languages  \
# 0  [{'english_name': 'Spanish', 'iso_639_1': 'es'...
# 1  [{'english_name': 'English', 'iso_639_1': 'en'...
# 2  [{'english_name': 'English', 'iso_639_1': 'en'...
# 3  [{'english_name': 'English', 'iso_639_1': 'en'...
# 4  [{'english_name': 'English', 'iso_639_1': 'en'...
#
#                                 production_countries
# 0        [{'iso_3166_1': 'AR', 'name': 'Argentina'}]
# 1  [{'iso_3166_1': 'CA', 'name': 'Canada'}, {'iso...
# 2  [{'iso_3166_1': 'US', 'name': 'United States o...
# 3           [{'iso_3166_1': 'FR', 'name': 'France'}]
# 4  [{'iso_3166_1': 'DE', 'name': 'Germany'}, {'is...
#
# [5 rows x 36 columns]

# %%
# Delete duplicate rows and reset index
merged_df = merged_df.drop_duplicates(subset=["title"])
merged_df = merged_df.reset_index(drop=True)
merged_df.head()
# Out:
#                                              web_url  \
# 0  https://www.nytimes.com/2023/05/25/movies/the-...
# 1  https://www.nytimes.com/2023/05/04/movies/you-...
# 2  https://www.nytimes.com/2023/04/21/movies/a-to...
# 3  https://www.nytimes.com/2023/04/20/movies/othe...
# 4  https://www.nytimes.com/2023/04/13/movies/one-...
#
#                                              snippet              source  \
# 0  A gynecologist and her patient form a horrifyi...  The New York Times
# 1  Religion comes between two girls falling in lo...  The New York Times
# 2  Rachael Leigh Cook stars in this bland rom-com...  The New York Times
# 3  A radiant Virginie Efira stars as a Parisian t...  The New York Times
# 4  A film adaptation of Taylor Jenkins Reid’s nov...  The New York Times
#
#                                             keywords  \
# 0  subject: Movies;creative_works: The Attachment...
# 1  subject: Movies;creative_works: You Can Live F...
# 2  subject: Movies;creative_works: A Tourist's Gu...
# 3  subject: Movies;persons: Zlotowski, Rebecca;cr...
# 4  subject: Movies;persons: Bracey, Luke (1989- )...
#
#                    pub_date  word_count  \
# 0  2023-05-25T11:00:03+0000         295
# 1  2023-05-04T11:00:08+0000         294
# 2  2023-04-21T07:03:25+0000         276
# 3  2023-04-20T15:35:13+0000         801
# 4  2023-04-13T11:00:06+0000         320
#
#                                        headline.main headline.kicker  \
# 0        ‘The Attachment Diaries’ Review: Love, Sick            None
# 1  ‘You Can Live Forever’ Review: Do You Love Me ...            None
# 2  ‘A Tourist’s Guide to Love’ Review: A Wearying...            None
# 3     ‘Other People’s Children’ Review: True Romance   Critic’s pick
# 4     ‘One True Loves’ Review: A Romance Lost at Sea            None
#
#   headline.content_kicker                 headline.print_headline  ...  \
# 0                    None                  The Attachment Diaries  ...
# 1                    None                    You Can Live Forever  ...
# 2                    None              A Tourist’s  Guide to Love  ...
# 3                    None  Intoxicating Love With a Sobering Turn  ...
# 4                    None                          One True Loves  ...
#
#       imdb_id                       poster_path  \
# 0  tt11359158   /hKZHk6I1p58ZeXbwjQok7DSWfZ.jpg
# 1  tt15782570  /10MJURrsPfDQmS2AP3fueOHJ0ch.jpg
# 2  tt20115096  /uWkpjbBe4gRZilXRXbYfsMUZMhz.jpg
# 3  tt15403712  /4vsQ4894pzd7nbvP5FoSOHaS1mI.jpg
# 4  tt14770620  /6MF3JvIZkluUijw9rvDKNqPT8kC.jpg
#
#                       backdrop_path original_language  \
# 0                              None                es
# 1  /sClvKM8C6a1DSPzMwkKjk8pNFDx.jpg                en
# 2  /z3Qc5a0grcCREAQKqI195P05dVf.jpg                en
# 3  /33UGFiijBDX18NHecj5xz5GkkHt.jpg                fr
# 4  /omkxkjj0IEhzOc9CBOwK2lrmHSk.jpg                en
#
#               original_title popularity vote_count  \
# 0                   El apego      0.997          2
# 1       You Can Live Forever      5.922         28
# 2  A Tourist's Guide to Love     23.381        144
# 3     Les Enfants des autres     13.638        169
# 4             One True Loves     17.637         59
#
#                                             homepage  \
# 0
# 1  https://gooddeedentertainment.com/you-can-live...
# 2             https://www.netflix.com/title/81424906
# 3  https://www.wildbunch.biz/movie/other-peoples-...
# 4
#
#                                     spoken_languages  \
# 0  [{'english_name': 'Spanish', 'iso_639_1': 'es'...
# 1  [{'english_name': 'English', 'iso_639_1': 'en'...
# 2  [{'english_name': 'English', 'iso_639_1': 'en'...
# 3  [{'english_name': 'English', 'iso_639_1': 'en'...
# 4  [{'english_name': 'English', 'iso_639_1': 'en'...
#
#                                 production_countries
# 0        [{'iso_3166_1': 'AR', 'name': 'Argentina'}]
# 1  [{'iso_3166_1': 'CA', 'name': 'Canada'}, {'iso...
# 2  [{'iso_3166_1': 'US', 'name': 'United States o...
# 3           [{'iso_3166_1': 'FR', 'name': 'France'}]
# 4  [{'iso_3166_1': 'DE', 'name': 'Germany'}, {'is...
#
# [5 rows x 36 columns]

# %%
# Export data to CSV without the index
merged_df.to_csv('merged_df.csv', index=False)
print("Exported merged_df.csv")
# Out:
# Exported merged_df.csv
